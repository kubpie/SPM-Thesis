# %% [markdown]
# <a href="https://colab.research.google.com/github/Qbbz/SSP/blob/colab-branch/KGCNcolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !git init
# !git config --global user.email "kuba.pietrak.94@gmail.com"
# !git config --global user.name "Qbbz"
# !git clone -b colab-branch https://github.com/Qbbz/SSP.git
# !git pull https://github.com/Qbbz/SSP.git colab-branch
# Out:
# Initialized empty Git repository in /content/.git/
# Cloning into 'SSP'...
# remote: Enumerating objects: 9069, done.
# remote: Counting objects: 100% (9069/9069), done.
# remote: Compressing objects: 100% (1324/1324), done.
# remote: Total 12071 (delta 8614), reused 8188 (delta 7737), pack-reused 3002
# Receiving objects: 100% (12071/12071), 44.07 MiB | 28.51 MiB/s, done.
# Resolving deltas: 100% (11460/11460), done.
# remote: Enumerating objects: 9055, done.
# remote: Counting objects: 100% (9055/9055), done.
# remote: Compressing objects: 100% (1316/1316), done.
# remote: Total 12039 (delta 8606), reused 8176 (delta 7731), pack-reused 2984
# Receiving objects: 100% (12039/12039), 43.51 MiB | 27.93 MiB/s, done.
# Resolving deltas: 100% (11436/11436), done.
# From https://github.com/Qbbz/SSP
#  * branch            colab-branch -> FETCH_HEAD

# %%
# !pip install -r requirements.txt
# Out:
# Collecting absl-py==0.8.0
#   Downloading https://files.pythonhosted.org/packages/3c/0d/7cbf64cac3f93617a2b6b079c0182e4a83a3e7a8964d3b0cc3d9758ba002/absl-py-0.8.0.tar.gz (102kB)
#      |████████████████████████████████| 112kB 3.4MB/s
# Collecting astor==0.8.0
#   Downloading https://files.pythonhosted.org/packages/d1/4f/950dfae467b384fc96bc6469de25d832534f6b4441033c39f914efd13418/astor-0.8.0-py2.py3-none-any.whl
# Collecting cloudpickle==1.2.2
#   Downloading https://files.pythonhosted.org/packages/c1/49/334e279caa3231255725c8e860fa93e72083567625573421db8875846c14/cloudpickle-1.2.2-py2.py3-none-any.whl
# Requirement already satisfied: contextlib2==0.5.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (0.5.5)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (0.10.0)
# Collecting decorator==4.4.0
#   Downloading https://files.pythonhosted.org/packages/5f/88/0075e461560a1e750a0dcbf77f1d9de775028c37a19a346a6c565a257399/decorator-4.4.0-py2.py3-none-any.whl
# Collecting dm-sonnet==1.35
#   Downloading https://files.pythonhosted.org/packages/49/8f/3178e49a9b463610a85b37f5206ae5ba5a49d00eb0c7135af652fd4bc22b/dm_sonnet-1.35-py3-none-any.whl (652kB)
#      |████████████████████████████████| 655kB 10.9MB/s
# Collecting future==0.17.1
#   Downloading https://files.pythonhosted.org/packages/90/52/e20466b85000a181e1e144fd8305caf2cf475e2f9674e797b222f8105f5f/future-0.17.1.tar.gz (829kB)
#      |████████████████████████████████| 829kB 17.7MB/s
# Collecting gast==0.3.1
#   Downloading https://files.pythonhosted.org/packages/4d/17/a92e707853e2fb48aea76dcdc200ea9a2f7d1ce6d1eff07ddfcf326184cb/gast-0.3.1.tar.gz
# Collecting google-pasta==0.1.7
#   Downloading https://files.pythonhosted.org/packages/d0/33/376510eb8d6246f3c30545f416b2263eee461e40940c2a4413c711bdf62d/google_pasta-0.1.7-py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 7.0MB/s
# Collecting graph-nets==1.0.4
#   Downloading https://files.pythonhosted.org/packages/1f/c6/a183077fe880d9837565ed9ddf8f62f888c9cf8cb488764d29d9f18547b5/graph_nets-1.0.4.tar.gz (54kB)
#      |████████████████████████████████| 61kB 6.9MB/s
# Collecting grpcio==1.23.0
#   Downloading https://files.pythonhosted.org/packages/30/31/6397193572c081e0fd1fec86a7a6b7ac497c27226281e7cb32f8c3705069/grpcio-1.23.0-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 22.3MB/s
# Collecting grakn-client==1.6.0
#   Downloading https://files.pythonhosted.org/packages/d5/1b/3175ae4c5cc4c039073533aae0e1d25aea0acdea3c29787b3ddfda8c970f/grakn-client-1.6.0.tar.gz (48kB)
#      |████████████████████████████████| 51kB 5.9MB/s
# Collecting grakn-kglib==0.2.1
#   Downloading https://files.pythonhosted.org/packages/ac/27/b3cbe649ab14ecbf214f1a32bbd1b870108a125b6dcf2b91f1e0f53e7771/grakn-kglib-0.2.1.tar.gz (89kB)
#      |████████████████████████████████| 92kB 10.3MB/s
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 15)) (2.10.0)
# Collecting Keras-Applications==1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 6.2MB/s
# Collecting Keras-Preprocessing==1.1.0
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 5.9MB/s
# Collecting kiwisolver==1.1.0
#   Downloading https://files.pythonhosted.org/packages/f8/a1/5742b56282449b1c0968197f63eae486eca2c35dcd334bab75ad524e0de1/kiwisolver-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (90kB)
#      |████████████████████████████████| 92kB 9.5MB/s
# Collecting Markdown==3.1.1
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
#      |████████████████████████████████| 92kB 9.0MB/s
# Collecting matplotlib==3.1.2
#   Downloading https://files.pythonhosted.org/packages/4e/11/06958a2b895a3853206dea1fb2a5b11bf044f626f90745987612af9c8f2c/matplotlib-3.1.2-cp36-cp36m-manylinux1_x86_64.whl (13.1MB)
#      |████████████████████████████████| 13.1MB 15.1MB/s
# Collecting networkx==2.3
#   Downloading https://files.pythonhosted.org/packages/85/08/f20aef11d4c343b557e5de6b9548761811eb16e438cee3d32b1c66c8566b/networkx-2.3.zip (1.7MB)
#      |████████████████████████████████| 1.8MB 47.3MB/s
# Collecting numpy==1.17.2
#   Downloading https://files.pythonhosted.org/packages/e5/e6/c3fdc53aed9fa19d6ff3abf97dfad768ae3afce1b7431f7500000816bda5/numpy-1.17.2-cp36-cp36m-manylinux1_x86_64.whl (20.4MB)
#      |████████████████████████████████| 20.4MB 1.3MB/s
# Collecting pandas==1.0.3
#   Downloading https://files.pythonhosted.org/packages/bb/71/8f53bdbcbc67c912b888b40def255767e475402e9df64050019149b1a943/pandas-1.0.3-cp36-cp36m-manylinux1_x86_64.whl (10.0MB)
#      |████████████████████████████████| 10.0MB 44.3MB/s
# Collecting protobuf==3.9.1
#   Downloading https://files.pythonhosted.org/packages/eb/f4/a27952733796330cd17c17ea1f974459f5fefbbad119c0f296a6d807fec3/protobuf-3.9.1-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 42.8MB/s
# Collecting pycebox==0.0.1
#   Downloading https://files.pythonhosted.org/packages/43/af/85e2e9dac1603a5c16d5989973fe4a96ee0424e0dbd39e1d43ee24556056/pycebox-0.0.1.tar.gz
# Collecting pyparsing==2.4.2
#   Downloading https://files.pythonhosted.org/packages/11/fa/0160cd525c62d7abd076a070ff02b2b94de589f1a9789774f17d7c54058e/pyparsing-2.4.2-py2.py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 8.3MB/s
# Collecting python-dateutil==2.8.0
#   Downloading https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl (226kB)
#      |████████████████████████████████| 235kB 49.0MB/s
# Collecting pytz==2019.2
#   Downloading https://files.pythonhosted.org/packages/87/76/46d697698a143e05f77bec5a526bf4e56a0be61d63425b68f4ba553b51f2/pytz-2019.2-py2.py3-none-any.whl (508kB)
#      |████████████████████████████████| 512kB 45.5MB/s
# Collecting scikit-learn==0.23.1
#   Downloading https://files.pythonhosted.org/packages/d9/3a/eb8d7bbe28f4787d140bb9df685b7d5bf6115c0e2a969def4027144e98b6/scikit_learn-0.23.1-cp36-cp36m-manylinux1_x86_64.whl (6.8MB)
#      |████████████████████████████████| 6.9MB 19.1MB/s
# Collecting scipy==1.3.1
#   Downloading https://files.pythonhosted.org/packages/29/50/a552a5aff252ae915f522e44642bb49a7b7b31677f9580cfd11bcc869976/scipy-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (25.2MB)
#      |████████████████████████████████| 25.2MB 127kB/s
# Requirement already satisfied: seaborn==0.10.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 31)) (0.10.1)
# Collecting semantic-version==2.8.2
#   Downloading https://files.pythonhosted.org/packages/0f/3b/8fee26649a86c71df159ed0ae7ac5f9ac38829bccd8a7404e116f903929b/semantic_version-2.8.2-py2.py3-none-any.whl
# Collecting six==1.12.0
#   Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting tensorboard==1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 42.7MB/s
# Collecting tensorflow==1.14.0
#   Downloading https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (109.2MB)
#      |████████████████████████████████| 109.2MB 50kB/s
# Collecting tensorflow-gpu==1.14.0
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 42kB/s
# Collecting tensorflow-estimator==1.14.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 3.3MB/s
# Collecting tensorflow-probability==0.7.0
#   Downloading https://files.pythonhosted.org/packages/3e/3a/c10b6c22320531c774402ac7186d1b673374e2a9d12502cbc8d811e4601c/tensorflow_probability-0.7.0-py2.py3-none-any.whl (981kB)
#      |████████████████████████████████| 983kB 17.5MB/s
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 39)) (1.1.0)
# Collecting Werkzeug==0.15.6
#   Downloading https://files.pythonhosted.org/packages/b7/61/c0a1adf9ad80db012ed7191af98fa05faa95fa09eceb71bb6fa8b66e6a43/Werkzeug-0.15.6-py2.py3-none-any.whl (328kB)
#      |████████████████████████████████| 337kB 22.8MB/s
# Collecting wrapt==1.11.2
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Collecting xlrd==1.2.0
#   Downloading https://files.pythonhosted.org/packages/b0/16/63576a1a001752e34bf8ea62e367997530dc553b689356b9879339cf45a4/xlrd-1.2.0-py2.py3-none-any.whl (103kB)
#      |████████████████████████████████| 112kB 27.0MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from graph-nets==1.0.4->-r requirements.txt (line 11)) (49.6.0)
# Collecting enum-compat==0.0.2
#   Downloading https://files.pythonhosted.org/packages/95/6e/26bdcba28b66126f66cf3e4cd03bcd63f7ae330d29ee68b1f6b623550bfa/enum-compat-0.0.2.tar.gz
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn==0.23.1->-r requirements.txt (line 29)) (0.16.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.14.0->-r requirements.txt (line 34)) (0.35.1)
# Building wheels for collected packages: absl-py, future, gast, graph-nets, grakn-client, grakn-kglib, networkx, pycebox, wrapt, enum-compat
#   Building wheel for absl-py (setup.py) ... done
#   Created wheel for absl-py: filename=absl_py-0.8.0-cp36-none-any.whl size=120989 sha256=a1cc285890d4f421fad6641e5580c645070bc821f024218d2e31a2f34c44300d
#   Stored in directory: /root/.cache/pip/wheels/9a/1e/7a/456008eb5e47fd5de792c6139df6d5b3d5f71d51c6a0b94799
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.17.1-cp36-none-any.whl size=488730 sha256=43ae47da4b3161e79a9206b1fc3be5117353144822fe291667fc624f2a7d7c21
#   Stored in directory: /root/.cache/pip/wheels/0c/61/d2/d6b7317325828fbb39ee6ad559dbe4664d0896da4721bf379e
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.3.1-cp36-none-any.whl size=9288 sha256=fb68fe4ec04f7f4dc95ea611e34ed404250be67e57289624ca43dcbd3fc7d5f9
#   Stored in directory: /root/.cache/pip/wheels/d0/e8/de/cf6666d48241d10e5d7cd53fb3b5e447ea8e659f767d669b11
#   Building wheel for graph-nets (setup.py) ... done
#   Created wheel for graph-nets: filename=graph_nets-1.0.4-cp36-none-any.whl size=62643 sha256=6af4f19217abb1fafab10e8b1de98c0f1de3583b3291c863b25dcee4252b9dbc
#   Stored in directory: /root/.cache/pip/wheels/29/d6/02/37fb236b8d18d2574d7dcc6f2ba5a31ef75b561c61ff2f97d7
#   Building wheel for grakn-client (setup.py) ... done
#   Created wheel for grakn-client: filename=grakn_client-1.6.0-py2.py3-none-any.whl size=59448 sha256=5ec94e17ee05d06373284c2e2ed24d27020557de0997beac9148e7ba6132fbd1
#   Stored in directory: /root/.cache/pip/wheels/9e/70/6c/911800241fd51114c20dbe7e68b3b475a87c4f0f92d82dc85b
#   Building wheel for grakn-kglib (setup.py) ... done
#   Created wheel for grakn-kglib: filename=grakn_kglib-0.2.1-py2.py3-none-any.whl size=111868 sha256=962cd9ac6a5b2ad1fba93e59a2124d194573bbb08a3d288c12123babffeb0f8b
#   Stored in directory: /root/.cache/pip/wheels/13/0d/2b/39653e0afb98d69bb5dfdf7250e8f2e4009f3c21b141846b32
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.3-py2.py3-none-any.whl size=1556409 sha256=54801c50a88cbb5e3902ae5436b0bde383e9b13192334a399c051494a6ff598c
#   Stored in directory: /root/.cache/pip/wheels/de/63/64/3699be2a9d0ccdb37c7f16329acf3863fd76eda58c39c737af
#   Building wheel for pycebox (setup.py) ... done
#   Created wheel for pycebox: filename=pycebox-0.0.1-cp36-none-any.whl size=3644 sha256=5bb0a94d4085f4d5cd72e313919c73809047ebf55972bd89592c923161b5a540
#   Stored in directory: /root/.cache/pip/wheels/58/5e/65/001126ca8b1f5c71e9571d09ba579e82bb0792062e7a82e77c
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.11.2-cp36-cp36m-linux_x86_64.whl size=67533 sha256=8f237d7c72ebf415d03398108761c12d79f32b63ba45effe34fc21fefff2d2ee
#   Stored in directory: /root/.cache/pip/wheels/d7/de/2e/efa132238792efb6459a96e85916ef8597fcb3d2ae51590dfd
#   Building wheel for enum-compat (setup.py) ... done
#   Created wheel for enum-compat: filename=enum_compat-0.0.2-cp36-none-any.whl size=1290 sha256=80b70a393bf0d1b0304ab7850b7a7068faadb30798fa251383011f3dc24dd583
#   Stored in directory: /root/.cache/pip/wheels/b1/69/f4/229af6a49beece0f688c9c73d9188769b89e698361d21ce96a
# Successfully built absl-py future gast graph-nets grakn-client grakn-kglib networkx pycebox wrapt enum-compat
# ERROR: google-colab 1.0.0 has requirement six~=1.15.0, but you'll have six 1.12.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ERROR: grakn-client 1.6.0 has requirement grpcio==1.16.0, but you'll have grpcio 1.23.0 which is incompatible.
# ERROR: grakn-client 1.6.0 has requirement protobuf==3.6.1, but you'll have protobuf 3.9.1 which is incompatible.
# ERROR: grakn-client 1.6.0 has requirement six==1.11.0, but you'll have six 1.12.0 which is incompatible.
# ERROR: grakn-kglib 0.2.1 has requirement matplotlib==3.1.1, but you'll have matplotlib 3.1.2 which is incompatible.
# ERROR: grakn-kglib 0.2.1 has requirement pandas==0.25.1, but you'll have pandas 1.0.3 which is incompatible.
# Installing collected packages: six, absl-py, astor, cloudpickle, decorator, numpy, tensorflow-probability, wrapt, semantic-version, dm-sonnet, future, gast, google-pasta, networkx, graph-nets, grpcio, protobuf, enum-compat, grakn-client, Keras-Applications, Keras-Preprocessing, kiwisolver, Markdown, python-dateutil, pyparsing, matplotlib, pytz, pandas, scipy, Werkzeug, tensorboard, tensorflow-estimator, tensorflow, grakn-kglib, pycebox, threadpoolctl, scikit-learn, tensorflow-gpu, xlrd
#   Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Found existing installation: absl-py 0.8.1
#     Uninstalling absl-py-0.8.1:
#       Successfully uninstalled absl-py-0.8.1
#   Found existing installation: astor 0.8.1
#     Uninstalling astor-0.8.1:
#       Successfully uninstalled astor-0.8.1
#   Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Found existing installation: tensorflow-probability 0.11.0
#     Uninstalling tensorflow-probability-0.11.0:
#       Successfully uninstalled tensorflow-probability-0.11.0
#   Found existing installation: wrapt 1.12.1
#     Uninstalling wrapt-1.12.1:
#       Successfully uninstalled wrapt-1.12.1
#   Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: google-pasta 0.2.0
#     Uninstalling google-pasta-0.2.0:
#       Successfully uninstalled google-pasta-0.2.0
#   Found existing installation: networkx 2.4
#     Uninstalling networkx-2.4:
#       Successfully uninstalled networkx-2.4
#   Found existing installation: grpcio 1.31.0
#     Uninstalling grpcio-1.31.0:
#       Successfully uninstalled grpcio-1.31.0
#   Found existing installation: protobuf 3.12.4
#     Uninstalling protobuf-3.12.4:
#       Successfully uninstalled protobuf-3.12.4
#   Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Found existing installation: kiwisolver 1.2.0
#     Uninstalling kiwisolver-1.2.0:
#       Successfully uninstalled kiwisolver-1.2.0
#   Found existing installation: Markdown 3.2.2
#     Uninstalling Markdown-3.2.2:
#       Successfully uninstalled Markdown-3.2.2
#   Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Found existing installation: pyparsing 2.4.7
#     Uninstalling pyparsing-2.4.7:
#       Successfully uninstalled pyparsing-2.4.7
#   Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# Successfully installed Keras-Applications-1.0.8 Keras-Preprocessing-1.1.0 Markdown-3.1.1 Werkzeug-0.15.6 absl-py-0.8.0 astor-0.8.0 cloudpickle-1.2.2 decorator-4.4.0 dm-sonnet-1.35 enum-compat-0.0.2 future-0.17.1 gast-0.3.1 google-pasta-0.1.7 grakn-client-1.6.0 grakn-kglib-0.2.1 graph-nets-1.0.4 grpcio-1.23.0 kiwisolver-1.1.0 matplotlib-3.1.2 networkx-2.3 numpy-1.17.2 pandas-1.0.3 protobuf-3.9.1 pycebox-0.0.1 pyparsing-2.4.2 python-dateutil-2.8.0 pytz-2019.2 scikit-learn-0.23.1 scipy-1.3.1 semantic-version-2.8.2 six-1.12.0 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0 tensorflow-probability-0.7.0 threadpoolctl-2.1.0 wrapt-1.11.2 xlrd-1.2.0

# %%
import copy
import inspect
import time
import pickle
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import pandas as pd
import os

from grakn.client import GraknClient
from KGCN.pipeline_mod import pipeline
#from kglib.kgcn.pipeline.pipeline import pipeline
from kglib.utils.graph.iterate import multidigraph_data_iterator
from kglib.utils.graph.query.query_graph import QueryGraph
from kglib.utils.grakn.type.type import get_thing_types, get_role_types
#from kglib.utils.graph.thing.queries_to_graph import build_graph_from_queries
from kglib.utils.graph.thing.queries_to_graph import combine_2_graphs, combine_n_graphs, concept_dict_from_concept_map
from kglib.utils.grakn.object.thing import build_thing
from kglib.utils.graph.thing.concept_dict_to_graph import concept_dict_to_graph
from sklearn.model_selection import train_test_split

### TENSORFLOW CONFIGURATION
import tensorflow as tf
print("Tensorflow version " + tf.__version__)

# Choose Config
use_tpu = False #@param {type:"boolean"} # TPU is not supported on TF 1.14
use_gpu = True 

# TPU Config
if use_tpu:
  assert 'COLAB_TPU_ADDR' in os.environ, 'Missing TPU; did you request a TPU in Notebook Settings?'
  if 'COLAB_TPU_ADDR' in os.environ:
    TF_MASTER = 'grpc://{}'.format(os.environ['COLAB_TPU_ADDR']) #tpu address
  else:
    TF_MASTER=''

  resolver = tf.distribute.cluster_resolver.TPUClusterResolver(TF_MASTER)
  tf.config.experimental_connect_to_cluster(resolver)
  tf.tpu.experimental.initialize_tpu_system(resolver)
  strategy = tf.distribute.experimental.TPUStrategy(resolver)

# GPU Config
if use_gpu:
  config = tf.ConfigProto()
  config.gpu_options.allow_growth=True
  sess = tf.Session(config=config)
  print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU'))) # Test tf for GPU acceleration

tf.reset_default_graph() #fix bugs with tensor of uknonw size
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation) #filter out mpl warnings
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.WARN) #filter out annoying messages about name format with ':'
import sys
from pathlib import Path
from mylib.data_prep import LoadData, FeatDuct, UndersampleData
# Out:
# Tensorflow version 1.14.0
# Num GPUs Available:  0
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-881291fd190f> in <module>()
#      56 import sys
#      57 from pathlib import Path
# ---> 58 from mylib.data_prep import LoadData, FeatDuct, UndersampleData
#
# /content/mylib/data_prep.py in <module>()
#      15 from sklearn.preprocessing import OneHotEncoder
#      16 from sklearn.model_selection import train_test_split
# ---> 17 from imblearn.over_sampling import SMOTENC
#      18
#      19 from mylib.ssp_features import SSPStat
#
# /usr/local/lib/python3.6/dist-packages/imblearn/__init__.py in <module>()
#      33 """
#      34
# ---> 35 from .base import FunctionSampler
#      36 from ._version import __version__
#      37
#
# /usr/local/lib/python3.6/dist-packages/imblearn/base.py in <module>()
#      13
#      14 from sklearn.base import BaseEstimator
# ---> 15 from sklearn.externals import six
#      16 from sklearn.preprocessing import label_binarize
#      17 from sklearn.utils import check_X_y
#
# ImportError: cannot import name 'six'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
PATH = os.getcwd() #+'\data\\'
#sys.path.insert(1, PATH + '/mylib/')
#print(PATH)
DATAPATH = Path(PATH+"/data/")
ALLDATA = LoadData(DATAPATH)
ALLDATA = FeatDuct(ALLDATA, Input_Only = True) #leave only model input
PROCESSED_DATA = pd.read_csv(str(DATAPATH)+"/ducts_data.csv")

KEYSPACE =  "kgcn_schema_full" #"kgcn500n2500" #"ssp_schema_slope0"  #"sampled_ssp_schema_kgcn"
URI = "localhost:48555"
SAVEPATH = str(DATAPATH) + "/nx_500n2500/" #nx_500n2500

# Existing elements in the graph are those that pre-exist in the graph, and should be predicted to continue to exist
PREEXISTS = 0
# Candidates are neither present in the input nor in the solution, they are negative samples
CANDIDATE = 1
# Elements to infer are the graph elements whose existence we want to predict to be true, they are positive samples
TO_INFER = 2

# Categorical Attribute types and the values of their categories
ses = ['Winter', 'Spring', 'Summer', 'Autumn']
locations = []
for ssp in ALLDATA['profile']:
    season = next((s for s in ses if s in ssp), False)
    location = ssp.replace(season, '')[:-1]
    location = location.replace(' ', '-')
    locations.append(location)
loc = np.unique(locations).tolist()

# Categorical Attributes and lists of their values
CATEGORICAL_ATTRIBUTES = {'season': ses,
                          'location': loc}
                          #duct_type': ["NotDuct","SLD","DC"]}
# Continuous Attribute types and their min and max values
"""
CONTINUOUS_ATTRIBUTES = {'depth': (0, 1500), 
                         'num_rays': (500, 15000), 
                         'slope': (-2, 2), 
                         'bottom_type': (1,2),
                         'length': (0, 44000),
                         'SSP_value':(1463.486641,1539.630391),
                         'grad': (-0.290954924,0.040374179),
                         'number_of_ducts': (1,2)}
"""
CONTINUOUS_ATTRIBUTES = {'depth': (0, 1200), 
                         'num_rays': (500, 2500), 
                         'slope': (-2, 2), 
                         'bottom_type': (1,2),
                         'length': (0, 44000),
                         'SSP_value':(1463.486641,1539.630391),
                         'grad': (-0.290954924,0.040374179),
                         'number_of_ducts': (1,2)}

TYPES_TO_IGNORE = ['candidate-convergence', 'scenario_id', 'probability_exists', 'probability_nonexists', 'probability_preexists']
ROLES_TO_IGNORE = ['candidate_resolution', 'candidate_scenario']

# The learner should see candidate relations the same as the ground truth relations, so adjust these candidates to
# look like their ground truth counterparts

TYPES_AND_ROLES_TO_OBFUSCATE = {'candidate-convergence': 'convergence',
                                'candidate_resolution': 'minimum_resolution',
                                'candidate_scenario': 'converged_scenario'}

# %%
def build_graph_from_queries(query_sampler_variable_graph_tuples, grakn_transaction,
                             concept_dict_converter=concept_dict_to_graph, infer=True):
    """
    Builds a graph of Things, interconnected by roles (and *has*), from a set of queries and graphs representing those
    queries (variable graphs)of those queries, over a Grakn transaction

    Args:
        infer: whether to use Grakn's inference engine
        query_sampler_variable_graph_tuples: A list of tuples, each tuple containing a query, a sampling function,
            and a variable_graph
        grakn_transaction: A Grakn transaction
        concept_dict_converter: The function to use to convert from concept_dicts to a Grakn model. This could be
            a typical model or a mathematical model

    Returns:
        A networkx graph
    """
    query_concept_graphs = []

    for query, sampler, variable_graph in query_sampler_variable_graph_tuples:

        concept_maps = sampler(grakn_transaction.query(query, infer=infer))
        concept_dicts = [concept_dict_from_concept_map(concept_map) for concept_map in concept_maps]
        #TODO: Implement removal of NotDuct cases at NetworkX level instead of query workaround
        """
        #print(concept_dicts)
        notaduct = 0
        for cd in concept_dicts:
            print(cd)
            for variable, thing in cd.items(): #key, value
                if variable == 'gd' and thing.value == 0.0:#and '0.0' in value:
                    print(variable, thing.value)
                    #cd.pop('gd')
                    #cd.pop('dct')
                    #cd.pop('SSP-channel')
                    #cd.pop()
                    #val = 'grad' in cd['gd']
                    #print(val)
                    #if '0.0' in value:
                    #    print('asdasda')
        """
        answer_concept_graphs = []
        for concept_dict in concept_dicts:
            try:
                answer_concept_graphs.append(concept_dict_converter(concept_dict, variable_graph))
            except ValueError as e:
                raise ValueError(str(e) + f'Encountered processing query:\n \"{query}\"')

        if len(answer_concept_graphs) > 1:
            query_concept_graph = combine_n_graphs(answer_concept_graphs)
            query_concept_graphs.append(query_concept_graph)
        else:
            if len(answer_concept_graphs) > 0:
                query_concept_graphs.append(answer_concept_graphs[0])
            else:
                warnings.warn(f'There were no results for query: \n\"{query}\"\nand so nothing will be added to the '
                              f'graph for this query')

    if len(query_concept_graphs) == 0:
        # Raise exception when none of the queries returned any results
        raise RuntimeError(f'The graph from queries: {[query_sampler_variable_graph_tuple[0] for query_sampler_variable_graph_tuple in query_sampler_variable_graph_tuples]}\n'
                           f'could not be created, since none of these queries returned results')

    concept_graph = combine_n_graphs(query_concept_graphs)
    #TODO: Remove NotDuct result from NetworkX graph completely: entity duct, attr grad 0, depth 0
     
    
    return concept_graph

def create_concept_graphs(example_indices, grakn_session, savepath):
    """
    Builds an in-memory graph for each example, with an scenario_id as an anchor for each example subgraph.
    Args:
        example_indices: The values used to anchor the subgraph queries within the entire knowledge graph
        =>> SCENARIO_ID
        grakn_session: Grakn Session

    Returns:
        In-memory graphs of Grakn subgraphs
        
    Outline:    
    For scnenario_id with open grakn session:
        0. check if the nx.graph for example doesn't exists already in the output directory
        if yes: load nx.graph from pickle file
        if no: 
            1. get_query_handles()
            2. build_graph_from_queries()
            3. obfuscate_labels() whatever it means
            4. graph.name = scenario_idx
            5. save ns.graph as pickle file
            6. append graph to list of graphs and return the list as func. output
            

    """
    
    graphs = []
    infer = True
    total = len(example_indices)
    # finds scenarios idx without ducts
    not_duct_idx = []
    for idx, sld, dc in zip(range(len(PROCESSED_DATA)),PROCESSED_DATA['SLD_depth'],PROCESSED_DATA['DC_axis']):
        if np.isnan(sld) and np.isnan(dc):
            not_duct_idx.append(idx)
        
    for it, scenario_idx in enumerate(example_indices):
        graph_filename = f'graph_{scenario_idx}.gpickle'
        if not os.path.exists(str(savepath)+"/"+graph_filename):
            print(f'[{it+1}|{total}] Creating graph for example {scenario_idx}')
            graph_query_handles = get_query_handles(scenario_idx, not_duct_idx)
            #print(graph_query_handles)
            with grakn_session.transaction().read() as tx:
                # Build a graph from the queries, samplers, and query graphs
                graph = build_graph_from_queries(graph_query_handles, tx, infer=infer)
    
            obfuscate_labels(graph, TYPES_AND_ROLES_TO_OBFUSCATE)
    
            graph.name = scenario_idx
            nx.write_gpickle(graph, savepath+graph_filename)
        
        else:
            print(f'[{it+1}|{total}] NetworkX graph loaded {graph_filename}')
            graph = nx.read_gpickle(savepath+graph_filename)    
        
        graphs.append(graph)

        #TODO: SWITCH plot NetworkX graphs 
        #new_graph = nx.Graph(graph)
        #nx.draw(new_graph, with_labels=True)
        #plt.show()
    return graphs

def obfuscate_labels(graph, types_and_roles_to_obfuscate):
    # Remove label leakage - change type labels that indicate candidates into non-candidates
    for data in multidigraph_data_iterator(graph):
        for label_to_obfuscate, with_label in types_and_roles_to_obfuscate.items():
            if data['type'] == label_to_obfuscate:
                data.update(type=with_label)
                break

def get_query_handles(scenario_idx, not_duct_idx):
        
    """
    Creates an iterable, each element containing a Graql query, a function to sample the answers, and a QueryGraph
    object which must be the Grakn graph representation of the query. This tuple is termed a "query_handle"
    Args:
        scenario_idx: A uniquely identifiable attribute value used to anchor the results of the queries to a specific subgraph
    Returns:
        query handles
    """
    # === Query variables ===
    conv, scn, ray, nray, src, dsrc, seg, dseg, l, s, srcp, bathy, bt, ssp, loc, ses,\
    sspval, dsspmax, speed, dssp, dct, ddct, gd, duct, nod = 'conv','scn','ray', 'nray',\
    'src', 'dsrc', 'seg', 'dseg','l','s','srcp','bathy','bt','ssp','loc','ses',\
    'sspval','dsspmax','speed','dssp','dct','ddct','gd','duct','nod'
    # dt, 'dt'
    
    
    # === Candidate Convergence ===
    candidate_convergence_query = inspect.cleandoc(f'''match
           $scn isa sound-propagation-scenario, has scenario_id {scenario_idx};'''
           '''$ray isa ray-input, has num_rays $nray;
           $conv(candidate_scenario: $scn, candidate_resolution: $ray) isa candidate-convergence; 
           get;''')    
 
    candidate_convergence_query_graph = (QueryGraph()
                                       .add_vars([conv], CANDIDATE)
                                       .add_vars([scn, ray, nray], PREEXISTS)
                                       .add_has_edge(ray, nray, PREEXISTS)
                                       .add_role_edge(conv, scn, 'candidate_scenario', CANDIDATE)
                                       .add_role_edge(conv, ray, 'candidate_resolution', CANDIDATE))

    
    if scenario_idx not in not_duct_idx:
        # === Convergence: SCN with ducts ===    
        convergence_query_full = inspect.cleandoc(
            f'''match 
            $scn isa sound-propagation-scenario, has scenario_id {scenario_idx};'''
            '''$ray isa ray-input, has num_rays $nray; 
            $src isa source, has depth $dsrc; 
            $seg isa bottom-segment, has depth $dseg, has length $l, has slope $s;
            $conv(converged_scenario: $scn, minimum_resolution: $ray) isa convergence;
            $srcp(defined_by_src: $scn, define_src: $src) isa src-position;
            $bathy(defined_by_bathy: $scn, define_bathy: $seg) isa bathymetry, has bottom_type $bt;
            $ssp isa SSP-vec, has location $loc, has season $ses, has SSP_value $sspval, has depth $dsspmax;
            $dct isa duct, has depth $ddct, has grad $gd;
            $speed(defined_by_SSP: $scn, define_SSP: $ssp) isa sound-speed;
            $duct(find_channel: $ssp, channel_exists: $dct) isa SSP-channel, has number_of_ducts $nod;
            $sspval has depth $dssp;
            {$dssp == $dsrc;} or {$dssp == $dseg;} or {$dssp == $ddct;} or {$dssp == $dsspmax;}; 
            get;'''
            )
        # has duct_type $dt,
        
        convergence_query_full_graph = (QueryGraph()
                                 .add_vars([conv], TO_INFER)
                                 .add_vars([scn, ray, nray, src, dsrc, seg, dseg, \
                                            l, s, srcp, bathy, bt, ssp, loc, ses, \
                                            sspval, dsspmax, speed, dssp, dct, ddct,\
                                            gd, duct, nod], PREEXISTS) #dt
                                 .add_has_edge(ray, nray, PREEXISTS)
                                 .add_has_edge(src, dsrc, PREEXISTS)
                                 .add_has_edge(seg, dseg, PREEXISTS)
                                 .add_has_edge(seg, l, PREEXISTS)
                                 .add_has_edge(seg, s, PREEXISTS)
                                 .add_has_edge(ssp, loc, PREEXISTS)
                                 .add_has_edge(ssp, ses, PREEXISTS)
                                 .add_has_edge(ssp, sspval, PREEXISTS)
                                 .add_has_edge(ssp, dsspmax, PREEXISTS)
                                 .add_has_edge(dct, ddct, PREEXISTS)
                                 #.add_has_edge(dct, dt, PREEXISTS)
                                 .add_has_edge(dct, gd, PREEXISTS)
                                 .add_has_edge(bathy, bt, PREEXISTS)
                                 .add_has_edge(duct, nod, PREEXISTS)
                                 .add_has_edge(sspval, dssp, PREEXISTS)
                                 .add_role_edge(conv, scn, 'converged_scenario', TO_INFER)
                                 .add_role_edge(conv, ray, 'minimum_resolution', TO_INFER)
                                 .add_role_edge(srcp, scn, 'defined_by_src', PREEXISTS)
                                 .add_role_edge(srcp, src, 'define_src', PREEXISTS)
                                 .add_role_edge(bathy, scn, 'defined_by_bathy', PREEXISTS)
                                 .add_role_edge(bathy, seg, 'define_bathy', PREEXISTS)
                                 .add_role_edge(speed, scn, 'defined_by_SSP', PREEXISTS)
                                 .add_role_edge(speed, ssp, 'define_SSP', PREEXISTS)
                                 .add_role_edge(duct, ssp, 'find_channel', PREEXISTS)
                                 .add_role_edge(duct, dct, 'channel_exists', PREEXISTS)
                                 )
        return [
            (convergence_query_full, lambda x: x, convergence_query_full_graph),
            (candidate_convergence_query, lambda x: x, candidate_convergence_query_graph)
            ]
    
    
    else:        
        # === Convergence: SCN with\without ducts ===
        convergence_query_reduced = inspect.cleandoc(
                f'''match 
                $scn isa sound-propagation-scenario, has scenario_id {scenario_idx};'''
                '''$ray isa ray-input, has num_rays $nray; 
                $src isa source, has depth $dsrc; 
                $seg isa bottom-segment, has depth $dseg, has length $l, has slope $s;
                $conv(converged_scenario: $scn, minimum_resolution: $ray) isa convergence;
                $srcp(defined_by_src: $scn, define_src: $src) isa src-position;
                $bathy(defined_by_bathy: $scn, define_bathy: $seg) isa bathymetry, has bottom_type $bt;
                $ssp isa SSP-vec, has location $loc, has season $ses, has SSP_value $sspval, has depth $dsspmax;
                $speed(defined_by_SSP: $scn, define_SSP: $ssp) isa sound-speed;
                $sspval has depth $dssp;
                {$dssp == $dsrc;} or {$dssp == $dseg;} or {$dssp == $dsspmax;}; 
                get;'''
                )
            
        convergence_query_reduced_graph = (QueryGraph()
                                 .add_vars([conv], TO_INFER)
                                 .add_vars([scn, ray, nray, src, dsrc, seg, dseg, \
                                            l, s, srcp, bathy, bt, ssp, loc, ses, \
                                            sspval, dsspmax, speed, dssp], PREEXISTS)
                                 .add_has_edge(ray, nray, PREEXISTS)
                                 .add_has_edge(src, dsrc, PREEXISTS)
                                 .add_has_edge(seg, dseg, PREEXISTS)
                                 .add_has_edge(seg, l, PREEXISTS)
                                 .add_has_edge(seg, s, PREEXISTS)
                                 .add_has_edge(ssp, loc, PREEXISTS)
                                 .add_has_edge(ssp, ses, PREEXISTS)
                                 .add_has_edge(ssp, sspval, PREEXISTS)
                                 .add_has_edge(ssp, dsspmax, PREEXISTS)
                                 .add_has_edge(bathy, bt, PREEXISTS)                           
                                 .add_has_edge(sspval, dssp, PREEXISTS)
                                 .add_role_edge(conv, scn, 'converged_scenario', TO_INFER) #TO_INFER VS CANDIDATE BELOW
                                 .add_role_edge(conv, ray, 'minimum_resolution', TO_INFER)
                                 .add_role_edge(srcp, scn, 'defined_by_src', PREEXISTS)
                                 .add_role_edge(srcp, src, 'define_src', PREEXISTS)
                                 .add_role_edge(bathy, scn, 'defined_by_bathy', PREEXISTS)
                                 .add_role_edge(bathy, seg, 'define_bathy', PREEXISTS)
                                 .add_role_edge(speed, scn, 'defined_by_SSP', PREEXISTS)
                                 .add_role_edge(speed, ssp, 'define_SSP', PREEXISTS)
                                 )    
            

        return [
            (convergence_query_reduced, lambda x: x, convergence_query_reduced_graph),
            (candidate_convergence_query, lambda x: x, candidate_convergence_query_graph)
            ]

def write_predictions_to_grakn(graphs, tx, commit = True):
    """
    Take predictions from the ML model, and insert representations of those predictions back into the graph.

    Args:
        graphs: graphs containing the concepts, with their class predictions and class probabilities
        tx: Grakn write transaction to use

    Returns: None

    """
    
    #TODO: Revise these loops and see why nothing is being predicted as data['prediction']=2 (exists?)
    for graph in graphs:
        for node, data in graph.nodes(data=True):
            if data['prediction'] == 2:
                concept = data['concept']
                concept_type = concept.type_label
                if concept_type == 'convergence' or concept_type == 'candidate-convergence':
                    neighbours = graph.neighbors(node)

                    for neighbour in neighbours:
                        concept = graph.nodes[neighbour]['concept']
                        if concept.type_label == 'sound-propagation-scenario':
                            scenario = concept
                        else:
                            ray = concept

                    p = data['probabilities']
                    query = (f'match '
                             f'$scn id {scenario.id}; '
                             f'$ray id {ray.id}; '
                             f'insert '
                             f'$conv(converged_scenario: $scn, minimum_resolution: $ray) isa convergence, '
                             f'has probability_exists {p[2]:.3f}, '
                             f'has probability_nonexists {p[1]:.3f}, '  
                             f'has probability_preexists {p[0]:.3f};')
                    print(query)
                    tx.query(query)
    if commit:
        tx.commit()

import re
def ubuntu_rand_fix(savepath):
    #savepath = PATH + '/networkx/'
    graphfiles = [f for f in os.listdir(savepath) if os.path.isfile(os.path.join(savepath, f))]
    example_idx = []
    for gfile in graphfiles:
        idx = re.findall(r'\d+', gfile)[0]    
        example_idx.append(idx)
    return example_idx

# %%
def prepare_data(session, data, train_split, validation_split, savepath, ubuntu_fix = True):
    """
    Args:
        data: full dataset with sorted scenario_id's that will be used for querying grakn
        train_split: size of the training set; 
        validaton_split: size of the validaton set subtracted from the test set; 
    
        Test set is further split down into test and validation so that
        test_set size = (1-train_split)*(1-validation_split)
        so i.e. train_split = 0.7, validation_split=0.33 results in:
        70% training set, 20.1% test set, 9.9% validation set
    """
    seed = 123
    
    y = data.pop('num_rays').to_frame()
    X = data
    # divide whole dataset into stratified train\test 
    X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, shuffle = True, random_state = seed, test_size=1-train_split)
    #if validation_split > 0:
    #divide test dataset into stratified test\validation subsets
    #X_test, X_val, y_test, y_val = train_test_split(
    #X_test, y_test, stratify=y_test, shuffle = True, random_state = seed, test_size=validation_split)
    
    training_data = [X_train, y_train]
    testing_data = [X_test, y_test]
    #validation_data = [X_val, y_val]
    
    # data was split and shuffled while mainating original indices 
    # now the training and test set indices are merged once again
    # and will be split again inside the grakn pipeline until tr_ge_split, without shuffle
    
    num_tr_graphs = len(X_test) + len(X_train)   
    #num_val_graphs = len(X_val)
    example_idx_tr = X_train.index.tolist() + X_test.index.tolist() #training and test sets indices merged for training

    # rand in linux and windows generates different number in effect the data selected in windows is different than ubuntu
    if ubuntu_fix:
        example_idx_tr = ubuntu_rand_fix(savepath)
    #example_idx_val = X_val.index.tolist()
    tr_ge_split = int(num_tr_graphs * train_split)  # Define graph number split in train graphs[:tr_ge_split] and test graphs[tr_ge_split:] sets
    #val_ge_split = int(len(X_val)*(1-validation_split))
    print(f'\nCREATING {num_tr_graphs} TRAINING\TEST GRAPHS')
    train_graphs = create_concept_graphs(example_idx_tr, session, savepath)  # Create validation graphs in networkX
    #print(f'\nCREATING {num_val_graphs} VALIDATION GRAPHS')
    #val_graphs = create_concept_graphs(example_idx_val, session, savepath) # Create training graphs in networkX
    
    return  train_graphs, tr_ge_split, training_data, testing_data #, val_graphs,  val_ge_split

def go_train(train_graphs, tr_ge_split, **kwargs):
    """
    Args:
           
    Parameters
    ----------
    train_graphs : networkx graphs obtained from grakn queries - the set contains both train and test graphs!
    tr_ge_split : int. value marking the number of training graphs in train_graphs
    save_fle : model filename to be saved as tf. checkpoin
    **kwargs : TYPE

    Returns:
    ge_graphs: Encoded in-memory graphs of Grakn concepts for generalisation
    solveds_tr: training fraction examples solved correctly
    solveds_ge: test/generalization fraction examples solved correctly

    """
    # Run the pipeline with prepared networkx graph
    #ge_graphs, solveds_tr, solveds_ge, graphs_enc, input_graphs, target_graphs, feed_dict 
    ge_graphs, solveds_tr, solveds_ge = pipeline(graphs = train_graphs,             
                                                tr_ge_split = tr_ge_split,                         
                                                do_test = False,
                                                **kwargs)
    
    training_evals= [solveds_tr, solveds_ge]   
    return ge_graphs, solveds_tr, solveds_ge

# %%
##### RUN THE PIPELINE  #####  

# DATA SELECTION FOR GRAKN TESTING
from data_analysis import ClassImbalance

#data = UndersampleData(ALLDATA, max_sample = 100)
#data = UndersampleData(data, max_sample = 30) #at 30 you got 507 nx graphs created, howeve with NotDuct at this point

# === 2 classes of 2000 sample 500/2500 ==== 
data_sparse2 = ALLDATA[(ALLDATA.loc[:,'num_rays'] == 500) | (ALLDATA.loc[:,'num_rays'] == 2500)]
data = UndersampleData(data_sparse2, max_sample = 300)
#data = data[(data.loc[:,'num_rays']==500) | (data.loc[:31,'num_rays'] == 2500)]
#data = data[:20]


class_population = ClassImbalance(data, plot = True)
plt.show()
print(class_population)

client = None
session = None
#KEYSPACE = 500n2500
"""
with session.transaction().read() as tx:
        # Change the terminology here onwards from thing -> node and role -> edge
        node_types = get_thing_types(tx)
        [node_types.remove(el) for el in TYPES_TO_IGNORE]
        edge_types = get_role_types(tx)
        [edge_types.remove(el) for el in ROLES_TO_IGNORE]
        print(f'Found node types: {node_types}')
        print(f'Found edge types: {edge_types}')
"""
node_types = ['SSP-vec', 'bottom-segment', 'duct', 'ray-input', 'source', 'sound-propagation-scenario', 'SSP_value', 'depth', 'location', 'season', 'grad', 'num_rays', 'length', 'slope', 'bottom_type', 'number_of_ducts', 'SSP-channel', 'convergence', 'src-position', 'bathymetry', 'sound-speed']
edge_types = ['has', 'channel_exists', 'define_SSP', 'find_channel', 'define_bathy', 'converged_scenario', 'defined_by_bathy', 'defined_by_src', 'minimum_resolution', 'define_src', 'defined_by_SSP']

train_graphs, tr_ge_split, training_data, testing_data = prepare_data(session, data, 
                                            train_split = 0.8, validation_split = 0., 
                                            ubuntu_fix= True, savepath = SAVEPATH)
#, val_graphs,  val_ge_split
# Out:
# {500: (300, 50.0), 2500: (300, 50.0)}
#
# CREATING 600 TRAINING\TEST GRAPHS
# [1|600] NetworkX graph loaded graph_5632.gpickle
# [2|600] NetworkX graph loaded graph_813.gpickle
# [3|600] NetworkX graph loaded graph_1579.gpickle
# [4|600] NetworkX graph loaded graph_6217.gpickle
# [5|600] NetworkX graph loaded graph_6460.gpickle
# [6|600] NetworkX graph loaded graph_284.gpickle
# [7|600] NetworkX graph loaded graph_8735.gpickle
# [8|600] NetworkX graph loaded graph_3480.gpickle
# [9|600] NetworkX graph loaded graph_8582.gpickle
# [10|600] NetworkX graph loaded graph_8815.gpickle
# [11|600] NetworkX graph loaded graph_6038.gpickle
# [12|600] NetworkX graph loaded graph_4742.gpickle
# [13|600] NetworkX graph loaded graph_3042.gpickle
# [14|600] NetworkX graph loaded graph_7839.gpickle
# [15|600] NetworkX graph loaded graph_7814.gpickle
# [16|600] NetworkX graph loaded graph_3200.gpickle
# [17|600] NetworkX graph loaded graph_2436.gpickle
# [18|600] NetworkX graph loaded graph_422.gpickle
# [19|600] NetworkX graph loaded graph_1581.gpickle
# [20|600] NetworkX graph loaded graph_5977.gpickle
# [21|600] NetworkX graph loaded graph_4525.gpickle
# [22|600] NetworkX graph loaded graph_761.gpickle
# [23|600] NetworkX graph loaded graph_7321.gpickle
# [24|600] NetworkX graph loaded graph_5606.gpickle
# [25|600] NetworkX graph loaded graph_3851.gpickle
# [26|600] NetworkX graph loaded graph_7643.gpickle
# [27|600] NetworkX graph loaded graph_2404.gpickle
# [28|600] NetworkX graph loaded graph_8185.gpickle
# [29|600] NetworkX graph loaded graph_3424.gpickle
# [30|600] NetworkX graph loaded graph_6478.gpickle
# [31|600] NetworkX graph loaded graph_5327.gpickle
# [32|600] NetworkX graph loaded graph_8999.gpickle
# [33|600] NetworkX graph loaded graph_7385.gpickle
# [34|600] NetworkX graph loaded graph_8967.gpickle
# [35|600] NetworkX graph loaded graph_7473.gpickle
# [36|600] NetworkX graph loaded graph_7248.gpickle
# [37|600] NetworkX graph loaded graph_8979.gpickle
# [38|600] NetworkX graph loaded graph_5382.gpickle
# [39|600] NetworkX graph loaded graph_7194.gpickle
# [40|600] NetworkX graph loaded graph_3091.gpickle
# [41|600] NetworkX graph loaded graph_6092.gpickle
# [42|600] NetworkX graph loaded graph_7634.gpickle
# [43|600] NetworkX graph loaded graph_159.gpickle
# [44|600] NetworkX graph loaded graph_3931.gpickle
# [45|600] NetworkX graph loaded graph_2884.gpickle
# [46|600] NetworkX graph loaded graph_7338.gpickle
# [47|600] NetworkX graph loaded graph_3012.gpickle
# [48|600] NetworkX graph loaded graph_2988.gpickle
# [49|600] NetworkX graph loaded graph_7823.gpickle
# [50|600] NetworkX graph loaded graph_8963.gpickle
# [51|600] NetworkX graph loaded graph_1586.gpickle
# [52|600] NetworkX graph loaded graph_6954.gpickle
# [53|600] NetworkX graph loaded graph_6943.gpickle
# [54|600] NetworkX graph loaded graph_2004.gpickle
# [55|600] NetworkX graph loaded graph_7039.gpickle
# [56|600] NetworkX graph loaded graph_7038.gpickle
# [57|600] NetworkX graph loaded graph_3143.gpickle
# [58|600] NetworkX graph loaded graph_7150.gpickle
# [59|600] NetworkX graph loaded graph_6852.gpickle
# [60|600] NetworkX graph loaded graph_1709.gpickle
# [61|600] NetworkX graph loaded graph_8079.gpickle
# [62|600] NetworkX graph loaded graph_2104.gpickle
# [63|600] NetworkX graph loaded graph_8176.gpickle
# [64|600] NetworkX graph loaded graph_7241.gpickle
# [65|600] NetworkX graph loaded graph_3055.gpickle
# [66|600] NetworkX graph loaded graph_4582.gpickle
# [67|600] NetworkX graph loaded graph_659.gpickle
# [68|600] NetworkX graph loaded graph_5430.gpickle
# [69|600] NetworkX graph loaded graph_2053.gpickle
# [70|600] NetworkX graph loaded graph_5976.gpickle
# [71|600] NetworkX graph loaded graph_6823.gpickle
# [72|600] NetworkX graph loaded graph_8071.gpickle
# [73|600] NetworkX graph loaded graph_3906.gpickle
# [74|600] NetworkX graph loaded graph_3495.gpickle
# [75|600] NetworkX graph loaded graph_4272.gpickle
# [76|600] NetworkX graph loaded graph_7289.gpickle
# [77|600] NetworkX graph loaded graph_8952.gpickle
# [78|600] NetworkX graph loaded graph_6568.gpickle
# [79|600] NetworkX graph loaded graph_8787.gpickle
# [80|600] NetworkX graph loaded graph_8983.gpickle
# [81|600] NetworkX graph loaded graph_9015.gpickle
# [82|600] NetworkX graph loaded graph_6470.gpickle
# [83|600] NetworkX graph loaded graph_8879.gpickle
# [84|600] NetworkX graph loaded graph_5629.gpickle
# [85|600] NetworkX graph loaded graph_8941.gpickle
# [86|600] NetworkX graph loaded graph_3737.gpickle
# [87|600] NetworkX graph loaded graph_3196.gpickle
# [88|600] NetworkX graph loaded graph_2467.gpickle
# [89|600] NetworkX graph loaded graph_6857.gpickle
# [90|600] NetworkX graph loaded graph_847.gpickle
# [91|600] NetworkX graph loaded graph_3564.gpickle
# [92|600] NetworkX graph loaded graph_7826.gpickle
# [93|600] NetworkX graph loaded graph_1332.gpickle
# [94|600] NetworkX graph loaded graph_3876.gpickle
# [95|600] NetworkX graph loaded graph_8843.gpickle
# [96|600] NetworkX graph loaded graph_8914.gpickle
# [97|600] NetworkX graph loaded graph_501.gpickle
# [98|600] NetworkX graph loaded graph_3478.gpickle
# [99|600] NetworkX graph loaded graph_6450.gpickle
# [100|600] NetworkX graph loaded graph_7117.gpickle
# [101|600] NetworkX graph loaded graph_1543.gpickle
# [102|600] NetworkX graph loaded graph_798.gpickle
# [103|600] NetworkX graph loaded graph_8875.gpickle
# [104|600] NetworkX graph loaded graph_5474.gpickle
# [105|600] NetworkX graph loaded graph_6657.gpickle
# [106|600] NetworkX graph loaded graph_5142.gpickle
# [107|600] NetworkX graph loaded graph_2964.gpickle
# [108|600] NetworkX graph loaded graph_113.gpickle
# [109|600] NetworkX graph loaded graph_385.gpickle
# [110|600] NetworkX graph loaded graph_7345.gpickle
# [111|600] NetworkX graph loaded graph_3963.gpickle
# [112|600] NetworkX graph loaded graph_5039.gpickle
# [113|600] NetworkX graph loaded graph_7109.gpickle
# [114|600] NetworkX graph loaded graph_7271.gpickle
# [115|600] NetworkX graph loaded graph_3067.gpickle
# [116|600] NetworkX graph loaded graph_291.gpickle
# [117|600] NetworkX graph loaded graph_7991.gpickle
# [118|600] NetworkX graph loaded graph_5263.gpickle
# [119|600] NetworkX graph loaded graph_2630.gpickle
# [120|600] NetworkX graph loaded graph_2080.gpickle
# [121|600] NetworkX graph loaded graph_7983.gpickle
# [122|600] NetworkX graph loaded graph_3760.gpickle
# [123|600] NetworkX graph loaded graph_7815.gpickle
# [124|600] NetworkX graph loaded graph_908.gpickle
# [125|600] NetworkX graph loaded graph_3051.gpickle
# [126|600] NetworkX graph loaded graph_96.gpickle
# [127|600] NetworkX graph loaded graph_5614.gpickle
# [128|600] NetworkX graph loaded graph_3811.gpickle
# [129|600] NetworkX graph loaded graph_7384.gpickle
# [130|600] NetworkX graph loaded graph_3318.gpickle
# [131|600] NetworkX graph loaded graph_5151.gpickle
# [132|600] NetworkX graph loaded graph_8613.gpickle
# [133|600] NetworkX graph loaded graph_5618.gpickle
# [134|600] NetworkX graph loaded graph_3076.gpickle
# [135|600] NetworkX graph loaded graph_3436.gpickle
# [136|600] NetworkX graph loaded graph_855.gpickle
# [137|600] NetworkX graph loaded graph_760.gpickle
# [138|600] NetworkX graph loaded graph_8510.gpickle
# [139|600] NetworkX graph loaded graph_508.gpickle
# [140|600] NetworkX graph loaded graph_7825.gpickle
# [141|600] NetworkX graph loaded graph_7817.gpickle
# [142|600] NetworkX graph loaded graph_8959.gpickle
# [143|600] NetworkX graph loaded graph_7159.gpickle
# [144|600] NetworkX graph loaded graph_3932.gpickle
# [145|600] NetworkX graph loaded graph_2700.gpickle
# [146|600] NetworkX graph loaded graph_8927.gpickle
# [147|600] NetworkX graph loaded graph_6583.gpickle
# [148|600] NetworkX graph loaded graph_6589.gpickle
# [149|600] NetworkX graph loaded graph_8175.gpickle
# [150|600] NetworkX graph loaded graph_3497.gpickle
# [151|600] NetworkX graph loaded graph_6154.gpickle
# [152|600] NetworkX graph loaded graph_3162.gpickle
# [153|600] NetworkX graph loaded graph_6186.gpickle
# [154|600] NetworkX graph loaded graph_8416.gpickle
# [155|600] NetworkX graph loaded graph_5.gpickle
# [156|600] NetworkX graph loaded graph_8779.gpickle
# [157|600] NetworkX graph loaded graph_2796.gpickle
# [158|600] NetworkX graph loaded graph_1318.gpickle
# [159|600] NetworkX graph loaded graph_6915.gpickle
# [160|600] NetworkX graph loaded graph_6577.gpickle
# [161|600] NetworkX graph loaded graph_1725.gpickle
# [162|600] NetworkX graph loaded graph_7432.gpickle
# [163|600] NetworkX graph loaded graph_4862.gpickle
# [164|600] NetworkX graph loaded graph_8892.gpickle
# [165|600] NetworkX graph loaded graph_7288.gpickle
# [166|600] NetworkX graph loaded graph_8900.gpickle
# [167|600] NetworkX graph loaded graph_8813.gpickle
# [168|600] NetworkX graph loaded graph_2117.gpickle
# [169|600] NetworkX graph loaded graph_1142.gpickle
# [170|600] NetworkX graph loaded graph_7393.gpickle
# [171|600] NetworkX graph loaded graph_3416.gpickle
# [172|600] NetworkX graph loaded graph_1900.gpickle
# [173|600] NetworkX graph loaded graph_8915.gpickle
# [174|600] NetworkX graph loaded graph_5262.gpickle
# [175|600] NetworkX graph loaded graph_7148.gpickle
# [176|600] NetworkX graph loaded graph_4.gpickle
# [177|600] NetworkX graph loaded graph_4816.gpickle
# [178|600] NetworkX graph loaded graph_949.gpickle
# [179|600] NetworkX graph loaded graph_6162.gpickle
# [180|600] NetworkX graph loaded graph_2714.gpickle
# [181|600] NetworkX graph loaded graph_6553.gpickle
# [182|600] NetworkX graph loaded graph_2864.gpickle
# [183|600] NetworkX graph loaded graph_6534.gpickle
# [184|600] NetworkX graph loaded graph_2507.gpickle
# [185|600] NetworkX graph loaded graph_4192.gpickle
# [186|600] NetworkX graph loaded graph_2844.gpickle
# [187|600] NetworkX graph loaded graph_443.gpickle
# [188|600] NetworkX graph loaded graph_1383.gpickle
# [189|600] NetworkX graph loaded graph_8205.gpickle
# [190|600] NetworkX graph loaded graph_877.gpickle
# [191|600] NetworkX graph loaded graph_7952.gpickle
# [192|600] NetworkX graph loaded graph_2079.gpickle
# [193|600] NetworkX graph loaded graph_9023.gpickle
# [194|600] NetworkX graph loaded graph_3338.gpickle
# [195|600] NetworkX graph loaded graph_2900.gpickle
# [196|600] NetworkX graph loaded graph_944.gpickle
# [197|600] NetworkX graph loaded graph_7158.gpickle
# [198|600] NetworkX graph loaded graph_6962.gpickle
# [199|600] NetworkX graph loaded graph_880.gpickle
# [200|600] NetworkX graph loaded graph_1141.gpickle
# [201|600] NetworkX graph loaded graph_4368.gpickle
# [202|600] NetworkX graph loaded graph_3089.gpickle
# [203|600] NetworkX graph loaded graph_8252.gpickle
# [204|600] NetworkX graph loaded graph_2708.gpickle
# [205|600] NetworkX graph loaded graph_7300.gpickle
# [206|600] NetworkX graph loaded graph_6575.gpickle
# [207|600] NetworkX graph loaded graph_3440.gpickle
# [208|600] NetworkX graph loaded graph_6942.gpickle
# [209|600] NetworkX graph loaded graph_2834.gpickle
# [210|600] NetworkX graph loaded graph_5008.gpickle
# [211|600] NetworkX graph loaded graph_239.gpickle
# [212|600] NetworkX graph loaded graph_8835.gpickle
# [213|600] NetworkX graph loaded graph_7836.gpickle
# [214|600] NetworkX graph loaded graph_3554.gpickle
# [215|600] NetworkX graph loaded graph_3373.gpickle
# [216|600] NetworkX graph loaded graph_2948.gpickle
# [217|600] NetworkX graph loaded graph_8119.gpickle
# [218|600] NetworkX graph loaded graph_3004.gpickle
# [219|600] NetworkX graph loaded graph_7916.gpickle
# [220|600] NetworkX graph loaded graph_828.gpickle
# [221|600] NetworkX graph loaded graph_583.gpickle
# [222|600] NetworkX graph loaded graph_2015.gpickle
# [223|600] NetworkX graph loaded graph_3886.gpickle
# [224|600] NetworkX graph loaded graph_8937.gpickle
# [225|600] NetworkX graph loaded graph_3800.gpickle
# [226|600] NetworkX graph loaded graph_4621.gpickle
# [227|600] NetworkX graph loaded graph_9019.gpickle
# [228|600] NetworkX graph loaded graph_3891.gpickle
# [229|600] NetworkX graph loaded graph_3449.gpickle
# [230|600] NetworkX graph loaded graph_8727.gpickle
# [231|600] NetworkX graph loaded graph_8798.gpickle
# [232|600] NetworkX graph loaded graph_741.gpickle
# [233|600] NetworkX graph loaded graph_3087.gpickle
# [234|600] NetworkX graph loaded graph_2756.gpickle
# [235|600] NetworkX graph loaded graph_3028.gpickle
# [236|600] NetworkX graph loaded graph_2020.gpickle
# [237|600] NetworkX graph loaded graph_7116.gpickle
# [238|600] NetworkX graph loaded graph_5112.gpickle
# [239|600] NetworkX graph loaded graph_2456.gpickle
# [240|600] NetworkX graph loaded graph_490.gpickle
# [241|600] NetworkX graph loaded graph_3010.gpickle
# [242|600] NetworkX graph loaded graph_7305.gpickle
# [243|600] NetworkX graph loaded graph_8167.gpickle
# [244|600] NetworkX graph loaded graph_5386.gpickle
# [245|600] NetworkX graph loaded graph_1304.gpickle
# [246|600] NetworkX graph loaded graph_3797.gpickle
# [247|600] NetworkX graph loaded graph_6008.gpickle
# [248|600] NetworkX graph loaded graph_8731.gpickle
# [249|600] NetworkX graph loaded graph_1356.gpickle
# [250|600] NetworkX graph loaded graph_3399.gpickle
# [251|600] NetworkX graph loaded graph_9004.gpickle
# [252|600] NetworkX graph loaded graph_3758.gpickle
# [253|600] NetworkX graph loaded graph_881.gpickle
# [254|600] NetworkX graph loaded graph_5141.gpickle
# [255|600] NetworkX graph loaded graph_8739.gpickle
# [256|600] NetworkX graph loaded graph_7364.gpickle
# [257|600] NetworkX graph loaded graph_1812.gpickle
# [258|600] NetworkX graph loaded graph_1899.gpickle
# [259|600] NetworkX graph loaded graph_2928.gpickle
# [260|600] NetworkX graph loaded graph_1617.gpickle
# [261|600] NetworkX graph loaded graph_8035.gpickle
# [262|600] NetworkX graph loaded graph_1382.gpickle
# [263|600] NetworkX graph loaded graph_8062.gpickle
# [264|600] NetworkX graph loaded graph_3020.gpickle
# [265|600] NetworkX graph loaded graph_8643.gpickle
# [266|600] NetworkX graph loaded graph_8801.gpickle
# [267|600] NetworkX graph loaded graph_943.gpickle
# [268|600] NetworkX graph loaded graph_1212.gpickle
# [269|600] NetworkX graph loaded graph_3406.gpickle
# [270|600] NetworkX graph loaded graph_5237.gpickle
# [271|600] NetworkX graph loaded graph_7344.gpickle
# [272|600] NetworkX graph loaded graph_7434.gpickle
# [273|600] NetworkX graph loaded graph_3080.gpickle
# [274|600] NetworkX graph loaded graph_6169.gpickle
# [275|600] NetworkX graph loaded graph_3002.gpickle
# [276|600] NetworkX graph loaded graph_7394.gpickle
# [277|600] NetworkX graph loaded graph_8866.gpickle
# [278|600] NetworkX graph loaded graph_5085.gpickle
# [279|600] NetworkX graph loaded graph_8687.gpickle
# [280|600] NetworkX graph loaded graph_4803.gpickle
# [281|600] NetworkX graph loaded graph_296.gpickle
# [282|600] NetworkX graph loaded graph_8989.gpickle
# [283|600] NetworkX graph loaded graph_4837.gpickle
# [284|600] NetworkX graph loaded graph_3081.gpickle
# [285|600] NetworkX graph loaded graph_6044.gpickle
# [286|600] NetworkX graph loaded graph_5209.gpickle
# [287|600] NetworkX graph loaded graph_1848.gpickle
# [288|600] NetworkX graph loaded graph_8931.gpickle
# [289|600] NetworkX graph loaded graph_3152.gpickle
# [290|600] NetworkX graph loaded graph_4917.gpickle
# [291|600] NetworkX graph loaded graph_5095.gpickle
# [292|600] NetworkX graph loaded graph_846.gpickle
# [293|600] NetworkX graph loaded graph_998.gpickle
# [294|600] NetworkX graph loaded graph_5016.gpickle
# [295|600] NetworkX graph loaded graph_5050.gpickle
# [296|600] NetworkX graph loaded graph_8775.gpickle
# [297|600] NetworkX graph loaded graph_6430.gpickle
# [298|600] NetworkX graph loaded graph_5752.gpickle
# [299|600] NetworkX graph loaded graph_2418.gpickle
# [300|600] NetworkX graph loaded graph_2641.gpickle
# [301|600] NetworkX graph loaded graph_8633.gpickle
# [302|600] NetworkX graph loaded graph_1258.gpickle
# [303|600] NetworkX graph loaded graph_5597.gpickle
# [304|600] NetworkX graph loaded graph_5172.gpickle
# [305|600] NetworkX graph loaded graph_8054.gpickle
# [306|600] NetworkX graph loaded graph_7822.gpickle
# [307|600] NetworkX graph loaded graph_3965.gpickle
# [308|600] NetworkX graph loaded graph_5200.gpickle
# [309|600] NetworkX graph loaded graph_3170.gpickle
# [310|600] NetworkX graph loaded graph_3862.gpickle
# [311|600] NetworkX graph loaded graph_2673.gpickle
# [312|600] NetworkX graph loaded graph_5048.gpickle
# [313|600] NetworkX graph loaded graph_8208.gpickle
# [314|600] NetworkX graph loaded graph_6084.gpickle
# [315|600] NetworkX graph loaded graph_343.gpickle
# [316|600] NetworkX graph loaded graph_7193.gpickle
# [317|600] NetworkX graph loaded graph_6687.gpickle
# [318|600] NetworkX graph loaded graph_7946.gpickle
# [319|600] NetworkX graph loaded graph_4805.gpickle
# [320|600] NetworkX graph loaded graph_7667.gpickle
# [321|600] NetworkX graph loaded graph_7336.gpickle
# [322|600] NetworkX graph loaded graph_7470.gpickle
# [323|600] NetworkX graph loaded graph_595.gpickle
# [324|600] NetworkX graph loaded graph_2872.gpickle
# [325|600] NetworkX graph loaded graph_8810.gpickle
# [326|600] NetworkX graph loaded graph_7412.gpickle
# [327|600] NetworkX graph loaded graph_2804.gpickle
# [328|600] NetworkX graph loaded graph_9001.gpickle
# [329|600] NetworkX graph loaded graph_5259.gpickle
# [330|600] NetworkX graph loaded graph_8183.gpickle
# [331|600] NetworkX graph loaded graph_7118.gpickle
# [332|600] NetworkX graph loaded graph_8871.gpickle
# [333|600] NetworkX graph loaded graph_2537.gpickle
# [334|600] NetworkX graph loaded graph_24.gpickle
# [335|600] NetworkX graph loaded graph_6851.gpickle
# [336|600] NetworkX graph loaded graph_2532.gpickle
# [337|600] NetworkX graph loaded graph_7471.gpickle
# [338|600] NetworkX graph loaded graph_7673.gpickle
# [339|600] NetworkX graph loaded graph_3106.gpickle
# [340|600] NetworkX graph loaded graph_1896.gpickle
# [341|600] NetworkX graph loaded graph_3812.gpickle
# [342|600] NetworkX graph loaded graph_9007.gpickle
# [343|600] NetworkX graph loaded graph_8919.gpickle
# [344|600] NetworkX graph loaded graph_3024.gpickle
# [345|600] NetworkX graph loaded graph_7020.gpickle
# [346|600] NetworkX graph loaded graph_4350.gpickle
# [347|600] NetworkX graph loaded graph_8831.gpickle
# [348|600] NetworkX graph loaded graph_8679.gpickle
# [349|600] NetworkX graph loaded graph_7883.gpickle
# [350|600] NetworkX graph loaded graph_6218.gpickle
# [351|600] NetworkX graph loaded graph_7157.gpickle
# [352|600] NetworkX graph loaded graph_1481.gpickle
# [353|600] NetworkX graph loaded graph_1997.gpickle
# [354|600] NetworkX graph loaded graph_7837.gpickle
# [355|600] NetworkX graph loaded graph_8055.gpickle
# [356|600] NetworkX graph loaded graph_7392.gpickle
# [357|600] NetworkX graph loaded graph_3044.gpickle
# [358|600] NetworkX graph loaded graph_5173.gpickle
# [359|600] NetworkX graph loaded graph_7297.gpickle
# [360|600] NetworkX graph loaded graph_7851.gpickle
# [361|600] NetworkX graph loaded graph_5049.gpickle
# [362|600] NetworkX graph loaded graph_6504.gpickle
# [363|600] NetworkX graph loaded graph_7298.gpickle
# [364|600] NetworkX graph loaded graph_6727.gpickle
# [365|600] NetworkX graph loaded graph_7440.gpickle
# [366|600] NetworkX graph loaded graph_6573.gpickle
# [367|600] NetworkX graph loaded graph_4588.gpickle
# [368|600] NetworkX graph loaded graph_1429.gpickle
# [369|600] NetworkX graph loaded graph_8191.gpickle
# [370|600] NetworkX graph loaded graph_6688.gpickle
# [371|600] NetworkX graph loaded graph_7312.gpickle
# [372|600] NetworkX graph loaded graph_1211.gpickle
# [373|600] NetworkX graph loaded graph_4146.gpickle
# [374|600] NetworkX graph loaded graph_7242.gpickle
# [375|600] NetworkX graph loaded graph_67.gpickle
# [376|600] NetworkX graph loaded graph_7156.gpickle
# [377|600] NetworkX graph loaded graph_3852.gpickle
# [378|600] NetworkX graph loaded graph_5502.gpickle
# [379|600] NetworkX graph loaded graph_7192.gpickle
# [380|600] NetworkX graph loaded graph_1105.gpickle
# [381|600] NetworkX graph loaded graph_90.gpickle
# [382|600] NetworkX graph loaded graph_5919.gpickle
# [383|600] NetworkX graph loaded graph_7200.gpickle
# [384|600] NetworkX graph loaded graph_8212.gpickle
# [385|600] NetworkX graph loaded graph_328.gpickle
# [386|600] NetworkX graph loaded graph_865.gpickle
# [387|600] NetworkX graph loaded graph_59.gpickle
# [388|600] NetworkX graph loaded graph_6867.gpickle
# [389|600] NetworkX graph loaded graph_3988.gpickle
# [390|600] NetworkX graph loaded graph_8635.gpickle
# [391|600] NetworkX graph loaded graph_2534.gpickle
# [392|600] NetworkX graph loaded graph_7840.gpickle
# [393|600] NetworkX graph loaded graph_5893.gpickle
# [394|600] NetworkX graph loaded graph_4031.gpickle
# [395|600] NetworkX graph loaded graph_1717.gpickle
# [396|600] NetworkX graph loaded graph_2665.gpickle
# [397|600] NetworkX graph loaded graph_6100.gpickle
# [398|600] NetworkX graph loaded graph_6545.gpickle
# [399|600] NetworkX graph loaded graph_2127.gpickle
# [400|600] NetworkX graph loaded graph_1820.gpickle
# [401|600] NetworkX graph loaded graph_4831.gpickle
# [402|600] NetworkX graph loaded graph_2748.gpickle
# [403|600] NetworkX graph loaded graph_2128.gpickle
# [404|600] NetworkX graph loaded graph_2628.gpickle
# [405|600] NetworkX graph loaded graph_6131.gpickle
# [406|600] NetworkX graph loaded graph_8444.gpickle
# [407|600] NetworkX graph loaded graph_4592.gpickle
# [408|600] NetworkX graph loaded graph_7639.gpickle
# [409|600] NetworkX graph loaded graph_8860.gpickle
# [410|600] NetworkX graph loaded graph_5564.gpickle
# [411|600] NetworkX graph loaded graph_7356.gpickle
# [412|600] NetworkX graph loaded graph_2892.gpickle
# [413|600] NetworkX graph loaded graph_8827.gpickle
# [414|600] NetworkX graph loaded graph_411.gpickle
# [415|600] NetworkX graph loaded graph_2016.gpickle
# [416|600] NetworkX graph loaded graph_2633.gpickle
# [417|600] NetworkX graph loaded graph_1901.gpickle
# [418|600] NetworkX graph loaded graph_3063.gpickle
# [419|600] NetworkX graph loaded graph_8823.gpickle
# [420|600] NetworkX graph loaded graph_1181.gpickle
# [421|600] NetworkX graph loaded graph_8580.gpickle
# [422|600] NetworkX graph loaded graph_5379.gpickle
# [423|600] NetworkX graph loaded graph_8991.gpickle
# [424|600] NetworkX graph loaded graph_5457.gpickle
# [425|600] NetworkX graph loaded graph_2593.gpickle
# [426|600] NetworkX graph loaded graph_4564.gpickle
# [427|600] NetworkX graph loaded graph_5195.gpickle
# [428|600] NetworkX graph loaded graph_3287.gpickle
# [429|600] NetworkX graph loaded graph_6163.gpickle
# [430|600] NetworkX graph loaded graph_651.gpickle
# [431|600] NetworkX graph loaded graph_1775.gpickle
# [432|600] NetworkX graph loaded graph_6627.gpickle
# [433|600] NetworkX graph loaded graph_3934.gpickle
# [434|600] NetworkX graph loaded graph_4369.gpickle
# [435|600] NetworkX graph loaded graph_3036.gpickle
# [436|600] NetworkX graph loaded graph_8602.gpickle
# [437|600] NetworkX graph loaded graph_2956.gpickle
# [438|600] NetworkX graph loaded graph_4226.gpickle
# [439|600] NetworkX graph loaded graph_6125.gpickle
# [440|600] NetworkX graph loaded graph_5516.gpickle
# [441|600] NetworkX graph loaded graph_5447.gpickle
# [442|600] NetworkX graph loaded graph_1780.gpickle
# [443|600] NetworkX graph loaded graph_5595.gpickle
# [444|600] NetworkX graph loaded graph_8023.gpickle
# [445|600] NetworkX graph loaded graph_3346.gpickle
# [446|600] NetworkX graph loaded graph_4154.gpickle
# [447|600] NetworkX graph loaded graph_7110.gpickle
# [448|600] NetworkX graph loaded graph_54.gpickle
# [449|600] NetworkX graph loaded graph_7472.gpickle
# [450|600] NetworkX graph loaded graph_7433.gpickle
# [451|600] NetworkX graph loaded graph_6434.gpickle
# [452|600] NetworkX graph loaded graph_402.gpickle
# [453|600] NetworkX graph loaded graph_8975.gpickle
# [454|600] NetworkX graph loaded graph_2192.gpickle
# [455|600] NetworkX graph loaded graph_582.gpickle
# [456|600] NetworkX graph loaded graph_3092.gpickle
# [457|600] NetworkX graph loaded graph_1733.gpickle
# [458|600] NetworkX graph loaded graph_3943.gpickle
# [459|600] NetworkX graph loaded graph_8811.gpickle
# [460|600] NetworkX graph loaded graph_5965.gpickle
# [461|600] NetworkX graph loaded graph_7018.gpickle
# [462|600] NetworkX graph loaded graph_5264.gpickle
# [463|600] NetworkX graph loaded graph_2193.gpickle
# [464|600] NetworkX graph loaded graph_4349.gpickle
# [465|600] NetworkX graph loaded graph_3964.gpickle
# [466|600] NetworkX graph loaded graph_909.gpickle
# [467|600] NetworkX graph loaded graph_2972.gpickle
# [468|600] NetworkX graph loaded graph_3428.gpickle
# [469|600] NetworkX graph loaded graph_1328.gpickle
# [470|600] NetworkX graph loaded graph_5268.gpickle
# [471|600] NetworkX graph loaded graph_7970.gpickle
# [472|600] NetworkX graph loaded graph_2174.gpickle
# [473|600] NetworkX graph loaded graph_4804.gpickle
# [474|600] NetworkX graph loaded graph_8220.gpickle
# [475|600] NetworkX graph loaded graph_3344.gpickle
# [476|600] NetworkX graph loaded graph_506.gpickle
# [477|600] NetworkX graph loaded graph_6170.gpickle
# [478|600] NetworkX graph loaded graph_7231.gpickle
# [479|600] NetworkX graph loaded graph_1774.gpickle
# [480|600] NetworkX graph loaded graph_4249.gpickle
# [481|600] NetworkX graph loaded graph_5100.gpickle
# [482|600] NetworkX graph loaded graph_3786.gpickle
# [483|600] NetworkX graph loaded graph_7296.gpickle
# [484|600] NetworkX graph loaded graph_6035.gpickle
# [485|600] NetworkX graph loaded graph_4584.gpickle
# [486|600] NetworkX graph loaded graph_2157.gpickle
# [487|600] NetworkX graph loaded graph_7848.gpickle
# [488|600] NetworkX graph loaded graph_3056.gpickle
# [489|600] NetworkX graph loaded graph_7108.gpickle
# [490|600] NetworkX graph loaded graph_6945.gpickle
# [491|600] NetworkX graph loaded graph_902.gpickle
# [492|600] NetworkX graph loaded graph_2622.gpickle
# [493|600] NetworkX graph loaded graph_7637.gpickle
# [494|600] NetworkX graph loaded graph_2852.gpickle
# [495|600] NetworkX graph loaded graph_6474.gpickle
# [496|600] NetworkX graph loaded graph_7852.gpickle
# [497|600] NetworkX graph loaded graph_1823.gpickle
# [498|600] NetworkX graph loaded graph_7280.gpickle
# [499|600] NetworkX graph loaded graph_4775.gpickle
# [500|600] NetworkX graph loaded graph_3305.gpickle
# [501|600] NetworkX graph loaded graph_4481.gpickle
# [502|600] NetworkX graph loaded graph_6750.gpickle
# [503|600] NetworkX graph loaded graph_7346.gpickle
# [504|600] NetworkX graph loaded graph_3088.gpickle
# [505|600] NetworkX graph loaded graph_6130.gpickle
# [506|600] NetworkX graph loaded graph_6210.gpickle
# [507|600] NetworkX graph loaded graph_3118.gpickle
# [508|600] NetworkX graph loaded graph_1146.gpickle
# [509|600] NetworkX graph loaded graph_1355.gpickle
# [510|600] NetworkX graph loaded graph_2996.gpickle
# [511|600] NetworkX graph loaded graph_8878.gpickle
# [512|600] NetworkX graph loaded graph_9027.gpickle
# [513|600] NetworkX graph loaded graph_4590.gpickle
# [514|600] NetworkX graph loaded graph_758.gpickle
# [515|600] NetworkX graph loaded graph_6518.gpickle
# [516|600] NetworkX graph loaded graph_5107.gpickle
# [517|600] NetworkX graph loaded graph_8628.gpickle
# [518|600] NetworkX graph loaded graph_5953.gpickle
# [519|600] NetworkX graph loaded graph_7908.gpickle
# [520|600] NetworkX graph loaded graph_3086.gpickle
# [521|600] NetworkX graph loaded graph_8854.gpickle
# [522|600] NetworkX graph loaded graph_7844.gpickle
# [523|600] NetworkX graph loaded graph_5187.gpickle
# [524|600] NetworkX graph loaded graph_7149.gpickle
# [525|600] NetworkX graph loaded graph_8245.gpickle
# [526|600] NetworkX graph loaded graph_7337.gpickle
# [527|600] NetworkX graph loaded graph_4344.gpickle
# [528|600] NetworkX graph loaded graph_3277.gpickle
# [529|600] NetworkX graph loaded graph_8605.gpickle
# [530|600] NetworkX graph loaded graph_2629.gpickle
# [531|600] NetworkX graph loaded graph_4912.gpickle
# [532|600] NetworkX graph loaded graph_3818.gpickle
# [533|600] NetworkX graph loaded graph_5825.gpickle
# [534|600] NetworkX graph loaded graph_6349.gpickle
# [535|600] NetworkX graph loaded graph_2555.gpickle
# [536|600] NetworkX graph loaded graph_8127.gpickle
# [537|600] NetworkX graph loaded graph_8353.gpickle
# [538|600] NetworkX graph loaded graph_2419.gpickle
# [539|600] NetworkX graph loaded graph_2940.gpickle
# [540|600] NetworkX graph loaded graph_7441.gpickle
# [541|600] NetworkX graph loaded graph_3893.gpickle
# [542|600] NetworkX graph loaded graph_5110.gpickle
# [543|600] NetworkX graph loaded graph_1949.gpickle
# [544|600] NetworkX graph loaded graph_4342.gpickle
# [545|600] NetworkX graph loaded graph_4367.gpickle
# [546|600] NetworkX graph loaded graph_942.gpickle
# [547|600] NetworkX graph loaded graph_3159.gpickle
# [548|600] NetworkX graph loaded graph_1381.gpickle
# [549|600] NetworkX graph loaded graph_8821.gpickle
# [550|600] NetworkX graph loaded graph_7833.gpickle
# [551|600] NetworkX graph loaded graph_1516.gpickle
# [552|600] NetworkX graph loaded graph_2980.gpickle
# [553|600] NetworkX graph loaded graph_7835.gpickle
# [554|600] NetworkX graph loaded graph_8971.gpickle
# [555|600] NetworkX graph loaded graph_2411.gpickle
# [556|600] NetworkX graph loaded graph_8923.gpickle
# [557|600] NetworkX graph loaded graph_6416.gpickle
# [558|600] NetworkX graph loaded graph_7250.gpickle
# [559|600] NetworkX graph loaded graph_6619.gpickle
# [560|600] NetworkX graph loaded graph_8178.gpickle
# [561|600] NetworkX graph loaded graph_2612.gpickle
# [562|600] NetworkX graph loaded graph_7818.gpickle
# [563|600] NetworkX graph loaded graph_8579.gpickle
# [564|600] NetworkX graph loaded graph_6629.gpickle
# [565|600] NetworkX graph loaded graph_5439.gpickle
# [566|600] NetworkX graph loaded graph_2018.gpickle
# [567|600] NetworkX graph loaded graph_1538.gpickle
# [568|600] NetworkX graph loaded graph_4957.gpickle
# [569|600] NetworkX graph loaded graph_5326.gpickle
# [570|600] NetworkX graph loaded graph_7442.gpickle
# [571|600] NetworkX graph loaded graph_8031.gpickle
# [572|600] NetworkX graph loaded graph_2591.gpickle
# [573|600] NetworkX graph loaded graph_5325.gpickle
# [574|600] NetworkX graph loaded graph_4673.gpickle
# [575|600] NetworkX graph loaded graph_2474.gpickle
# [576|600] NetworkX graph loaded graph_3496.gpickle
# [577|600] NetworkX graph loaded graph_8193.gpickle
# [578|600] NetworkX graph loaded graph_7290.gpickle
# [579|600] NetworkX graph loaded graph_7065.gpickle
# [580|600] NetworkX graph loaded graph_5751.gpickle
# [581|600] NetworkX graph loaded graph_1813.gpickle
# [582|600] NetworkX graph loaded graph_3892.gpickle
# [583|600] NetworkX graph loaded graph_6542.gpickle
# [584|600] NetworkX graph loaded graph_4428.gpickle
# [585|600] NetworkX graph loaded graph_3969.gpickle
# [586|600] NetworkX graph loaded graph_8783.gpickle
# [587|600] NetworkX graph loaded graph_7386.gpickle
# [588|600] NetworkX graph loaded graph_6658.gpickle
# [589|600] NetworkX graph loaded graph_1407.gpickle
# [590|600] NetworkX graph loaded graph_7875.gpickle
# [591|600] NetworkX graph loaded graph_7249.gpickle
# [592|600] NetworkX graph loaded graph_5462.gpickle
# [593|600] NetworkX graph loaded graph_4476.gpickle
# [594|600] NetworkX graph loaded graph_7202.gpickle
# [595|600] NetworkX graph loaded graph_5236.gpickle
# [596|600] NetworkX graph loaded graph_269.gpickle
# [597|600] NetworkX graph loaded graph_1819.gpickle
# [598|600] NetworkX graph loaded graph_1154.gpickle
# [599|600] NetworkX graph loaded graph_2433.gpickle
# [600|600] NetworkX graph loaded graph_279.gpickle
#
#
# TRAINING
#
#
# Saving output to directory:events/ssp_2class/1598378027.5824552/training_summary.ckpt
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# RoleEmbedder/embed/embeddings:0
# RoleEmbedder/layer_norm/gamma:0
# RoleEmbedder/layer_norm/beta:0
# KGCN/kg_encoder/edge_model/mlp/linear_0/w:0
# KGCN/kg_encoder/edge_model/mlp/linear_0/b:0
# KGCN/kg_encoder/edge_model/mlp/linear_1/w:0
# KGCN/kg_encoder/edge_model/mlp/linear_1/b:0
# KGCN/kg_encoder/edge_model/layer_norm/gamma:0
# KGCN/kg_encoder/edge_model/layer_norm/beta:0
# ThingEmbedder/embed/embeddings:0
# ThingEmbedder/layer_norm/gamma:0
# ThingEmbedder/layer_norm/beta:0
# ThingEmbedder/typewise_encoder/location_cat_embedder/embed/embeddings:0
# ThingEmbedder/typewise_encoder/location_cat_embedder_1/embed/embeddings:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder/mlp/linear_0/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder/mlp/linear_0/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder/mlp/linear_1/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder/mlp/linear_1/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder/mlp/linear_2/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder/mlp/linear_2/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder/layer_norm/gamma:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder/layer_norm/beta:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_1/mlp/linear_0/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_1/mlp/linear_0/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_1/mlp/linear_1/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_1/mlp/linear_1/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_1/mlp/linear_2/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_1/mlp/linear_2/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_1/layer_norm/gamma:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_1/layer_norm/beta:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_2/mlp/linear_0/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_2/mlp/linear_0/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_2/mlp/linear_1/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_2/mlp/linear_1/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_2/mlp/linear_2/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_2/mlp/linear_2/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_2/layer_norm/gamma:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_2/layer_norm/beta:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_3/mlp/linear_0/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_3/mlp/linear_0/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_3/mlp/linear_1/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_3/mlp/linear_1/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_3/mlp/linear_2/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_3/mlp/linear_2/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_3/layer_norm/gamma:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_3/layer_norm/beta:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_4/mlp/linear_0/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_4/mlp/linear_0/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_4/mlp/linear_1/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_4/mlp/linear_1/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_4/mlp/linear_2/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_4/mlp/linear_2/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_4/layer_norm/gamma:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_4/layer_norm/beta:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_5/mlp/linear_0/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_5/mlp/linear_0/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_5/mlp/linear_1/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_5/mlp/linear_1/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_5/mlp/linear_2/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_5/mlp/linear_2/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_5/layer_norm/gamma:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_5/layer_norm/beta:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_6/mlp/linear_0/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_6/mlp/linear_0/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_6/mlp/linear_1/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_6/mlp/linear_1/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_6/mlp/linear_2/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_6/mlp/linear_2/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_6/layer_norm/gamma:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_6/layer_norm/beta:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_7/mlp/linear_0/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_7/mlp/linear_0/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_7/mlp/linear_1/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_7/mlp/linear_1/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_7/mlp/linear_2/w:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_7/mlp/linear_2/b:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_7/layer_norm/gamma:0
# ThingEmbedder/typewise_encoder/number_of_ducts_cat_embedder_7/layer_norm/beta:0
# KGCN/kg_encoder/node_model/mlp/linear_0/w:0
# KGCN/kg_encoder/node_model/mlp/linear_0/b:0
# KGCN/kg_encoder/node_model/mlp/linear_1/w:0
# KGCN/kg_encoder/node_model/mlp/linear_1/b:0
# KGCN/kg_encoder/node_model/layer_norm/gamma:0
# KGCN/kg_encoder/node_model/layer_norm/beta:0
# KGCN/MLPInteractionNetwork/interaction_network/edge_block/mlp/linear_0/w:0
# KGCN/MLPInteractionNetwork/interaction_network/edge_block/mlp/linear_0/b:0
# KGCN/MLPInteractionNetwork/interaction_network/edge_block/mlp/linear_1/w:0
# KGCN/MLPInteractionNetwork/interaction_network/edge_block/mlp/linear_1/b:0
# KGCN/MLPInteractionNetwork/interaction_network/edge_block/layer_norm/gamma:0
# KGCN/MLPInteractionNetwork/interaction_network/edge_block/layer_norm/beta:0
# KGCN/MLPInteractionNetwork/interaction_network/node_block/mlp/linear_0/w:0
# KGCN/MLPInteractionNetwork/interaction_network/node_block/mlp/linear_0/b:0
# KGCN/MLPInteractionNetwork/interaction_network/node_block/mlp/linear_1/w:0
# KGCN/MLPInteractionNetwork/interaction_network/node_block/mlp/linear_1/b:0
# KGCN/MLPInteractionNetwork/interaction_network/node_block/layer_norm/gamma:0
# KGCN/MLPInteractionNetwork/interaction_network/node_block/layer_norm/beta:0
# KGCN/MLPGraphIndependent/graph_independent/edge_model/mlp/linear_0/w:0
# KGCN/MLPGraphIndependent/graph_independent/edge_model/mlp/linear_0/b:0
# KGCN/MLPGraphIndependent/graph_independent/edge_model/mlp/linear_1/w:0
# KGCN/MLPGraphIndependent/graph_independent/edge_model/mlp/linear_1/b:0
# KGCN/MLPGraphIndependent/graph_independent/edge_model/layer_norm/gamma:0
# KGCN/MLPGraphIndependent/graph_independent/edge_model/layer_norm/beta:0
# KGCN/MLPGraphIndependent/graph_independent/node_model/mlp/linear_0/w:0
# KGCN/MLPGraphIndependent/graph_independent/node_model/mlp/linear_0/b:0
# KGCN/MLPGraphIndependent/graph_independent/node_model/mlp/linear_1/w:0
# KGCN/MLPGraphIndependent/graph_independent/node_model/mlp/linear_1/b:0
# KGCN/MLPGraphIndependent/graph_independent/node_model/layer_norm/gamma:0
# KGCN/MLPGraphIndependent/graph_independent/node_model/layer_norm/beta:0
# KGCN/graph_independent/edge_model/edge_output/w:0
# KGCN/graph_independent/edge_model/edge_output/b:0
# KGCN/graph_independent/node_model/node_output/w:0
# KGCN/graph_independent/node_model/node_output/b:0
#
# FileWriter: ./events/ssp_2class/1598378027.5824552/
# # (iteration number), T (elapsed seconds), Ltr (training loss), Lge (test/generalization loss), Ctr (training fraction nodes/edges labeled correctly), Str (training fraction examples solved correctly), Cge (test/generalization fraction nodes/edges labeled correctly), Sge (test/generalization fraction examples solved correctly)
# # 00000, T 14.5, Ltr 0.9474, Lge 0.9482, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00050, T 58.6, Ltr 0.9003, Lge 0.9008, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00100, T 92.7, Ltr 0.8777, Lge 0.8770, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00150, T 125.6, Ltr 0.8602, Lge 0.8604, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00200, T 158.6, Ltr 0.8453, Lge 0.8475, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00250, T 191.7, Ltr 0.8348, Lge 0.8387, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00300, T 224.9, Ltr 0.8263, Lge 0.8300, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00350, T 258.0, Ltr 0.8187, Lge 0.8229, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00400, T 291.1, Ltr 0.8125, Lge 0.8163, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00450, T 324.1, Ltr 0.8061, Lge 0.8102, Ctr 0.4990, Str 0.0729, Cge 0.4833, Sge 0.0750
# # 00500, T 357.0, Ltr 0.8007, Lge 0.8034, Ctr 0.4885, Str 0.0271, Cge 0.4917, Sge 0.0333
# # 00550, T 390.0, Ltr 0.7958, Lge 0.7992, Ctr 0.4896, Str 0.0146, Cge 0.4958, Sge 0.0250
# # 00600, T 423.0, Ltr 0.7914, Lge 0.7941, Ctr 0.4896, Str 0.0208, Cge 0.4917, Sge 0.0250
# # 00650, T 456.0, Ltr 0.7864, Lge 0.7902, Ctr 0.5010, Str 0.0187, Cge 0.4917, Sge 0.0083
# # 00700, T 489.1, Ltr 0.7792, Lge 0.7818, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00750, T 522.1, Ltr 0.7745, Lge 0.7771, Ctr 0.5000, Str 0.0000, Cge 0.5000, Sge 0.0000
# # 00800, T 555.2, Ltr 0.7681, Lge 0.7702, Ctr 0.5052, Str 0.0208, Cge 0.4958, Sge 0.0000
# # 00850, T 588.3, Ltr 0.7642, Lge 0.7725, Ctr 0.4948, Str 0.0625, Cge 0.5250, Sge 0.1750
# # 00900, T 621.3, Ltr 0.7583, Lge 0.7669, Ctr 0.4969, Str 0.0312, Cge 0.4833, Sge 0.0083
# # 00950, T 654.2, Ltr 0.7550, Lge 0.7762, Ctr 0.5208, Str 0.1250, Cge 0.4792, Sge 0.0750
# # 01000, T 687.2, Ltr 0.7524, Lge 0.7571, Ctr 0.5094, Str 0.0583, Cge 0.4917, Sge 0.0417
# # 01050, T 719.9, Ltr 0.7515, Lge 0.7515, Ctr 0.5000, Str 0.0833, Cge 0.5208, Sge 0.0833
# # 01100, T 752.4, Ltr 0.7484, Lge 0.7477, Ctr 0.4917, Str 0.0521, Cge 0.5083, Sge 0.0500
# # 01150, T 784.9, Ltr 0.7464, Lge 0.7471, Ctr 0.5000, Str 0.0813, Cge 0.4875, Sge 0.0917
# # 01200, T 817.8, Ltr 0.7451, Lge 0.7446, Ctr 0.5052, Str 0.0854, Cge 0.5083, Sge 0.0667
# # 01250, T 850.6, Ltr 0.7435, Lge 0.7445, Ctr 0.5188, Str 0.0979, Cge 0.4625, Sge 0.1000
# # 01300, T 883.4, Ltr 0.7420, Lge 0.7408, Ctr 0.5167, Str 0.0854, Cge 0.5083, Sge 0.0833
# # 01350, T 916.2, Ltr 0.7407, Lge 0.7407, Ctr 0.5115, Str 0.0688, Cge 0.4917, Sge 0.0250
# # 01400, T 949.1, Ltr 0.7394, Lge 0.7379, Ctr 0.5083, Str 0.0979, Cge 0.5417, Sge 0.1167
# # 01450, T 982.0, Ltr 0.7381, Lge 0.7396, Ctr 0.4969, Str 0.0938, Cge 0.4750, Sge 0.1333
# # 01500, T 1014.9, Ltr 0.7374, Lge 0.7348, Ctr 0.4958, Str 0.0896, Cge 0.5458, Sge 0.1667
# # 01550, T 1047.8, Ltr 0.7355, Lge 0.7354, Ctr 0.5271, Str 0.1979, Cge 0.4667, Sge 0.1000
# # 01600, T 1080.6, Ltr 0.7341, Lge 0.7331, Ctr 0.5146, Str 0.1229, Cge 0.4750, Sge 0.1083
# # 01650, T 1113.1, Ltr 0.7336, Lge 0.7331, Ctr 0.5125, Str 0.0729, Cge 0.5125, Sge 0.0750
# # 01700, T 1146.0, Ltr 0.7320, Lge 0.7773, Ctr 0.5240, Str 0.1292, Cge 0.4792, Sge 0.1083
# # 01750, T 1178.7, Ltr 0.7316, Lge 0.7324, Ctr 0.5167, Str 0.1062, Cge 0.4917, Sge 0.0917
# # 01800, T 1211.5, Ltr 0.7333, Lge 0.8044, Ctr 0.4979, Str 0.0979, Cge 0.5083, Sge 0.0500
# # 01850, T 1244.3, Ltr 0.7300, Lge 0.7243, Ctr 0.5010, Str 0.1187, Cge 0.5250, Sge 0.1000
# # 01900, T 1277.1, Ltr 0.7300, Lge 0.7301, Ctr 0.4969, Str 0.0104, Cge 0.4917, Sge 0.0167
# # 01950, T 1310.1, Ltr 0.7287, Lge 0.7294, Ctr 0.4802, Str 0.0896, Cge 0.4833, Sge 0.0667
# # 02000, T 1342.9, Ltr 0.7279, Lge 0.7273, Ctr 0.5062, Str 0.1167, Cge 0.5000, Sge 0.0750
# # 02050, T 1375.6, Ltr 0.7276, Lge 0.7415, Ctr 0.4927, Str 0.1125, Cge 0.4667, Sge 0.0833
# # 02100, T 1408.3, Ltr 0.7268, Lge 0.7264, Ctr 0.5031, Str 0.0563, Cge 0.5125, Sge 0.0583
# # 02150, T 1441.3, Ltr 0.7271, Lge 0.7471, Ctr 0.4865, Str 0.0854, Cge 0.5125, Sge 0.0583
# # 02200, T 1474.2, Ltr 0.7252, Lge 0.7338, Ctr 0.5125, Str 0.1167, Cge 0.4417, Sge 0.0750
# # 02250, T 1506.8, Ltr 0.7245, Lge 0.7238, Ctr 0.5073, Str 0.1104, Cge 0.4917, Sge 0.1417
# # 02300, T 1539.8, Ltr 0.7242, Lge 0.7210, Ctr 0.4792, Str 0.1542, Cge 0.5458, Sge 0.1583
# # 02350, T 1572.7, Ltr 0.7233, Lge 0.7231, Ctr 0.5333, Str 0.1938, Cge 0.4875, Sge 0.1083
# # 02400, T 1605.6, Ltr 0.7230, Lge 0.7227, Ctr 0.5052, Str 0.1292, Cge 0.5000, Sge 0.2000
# # 02450, T 1638.5, Ltr 0.7226, Lge 0.7186, Ctr 0.5219, Str 0.1521, Cge 0.4708, Sge 0.1167
# # 02500, T 1671.8, Ltr 0.7220, Lge 0.7176, Ctr 0.4958, Str 0.1771, Cge 0.4750, Sge 0.2250
# # 02550, T 1704.9, Ltr 0.7219, Lge 0.7211, Ctr 0.5073, Str 0.1938, Cge 0.5042, Sge 0.0667
# # 02600, T 1738.1, Ltr 0.7213, Lge 0.7207, Ctr 0.5177, Str 0.0938, Cge 0.5000, Sge 0.0250
# # 02650, T 1771.4, Ltr 0.7200, Lge 0.7216, Ctr 0.5073, Str 0.1792, Cge 0.4542, Sge 0.1250
# # 02700, T 1804.6, Ltr 0.7196, Lge 0.7191, Ctr 0.4969, Str 0.2167, Cge 0.4917, Sge 0.0583
# # 02750, T 1837.9, Ltr 0.7200, Lge 0.7213, Ctr 0.4990, Str 0.0771, Cge 0.5125, Sge 0.1250
# # 02800, T 1871.2, Ltr 0.7189, Lge 0.7228, Ctr 0.5250, Str 0.1437, Cge 0.5167, Sge 0.1417
# # 02850, T 1904.3, Ltr 0.7190, Lge 0.7106, Ctr 0.4948, Str 0.1854, Cge 0.5417, Sge 0.1250
# # 02900, T 1937.5, Ltr 0.7177, Lge 0.7327, Ctr 0.5302, Str 0.1625, Cge 0.4792, Sge 0.1417
# # 02950, T 1970.7, Ltr 0.7172, Lge 0.7142, Ctr 0.5312, Str 0.1458, Cge 0.5333, Sge 0.2500
# # 03000, T 2004.0, Ltr 0.7190, Lge 0.7282, Ctr 0.4833, Str 0.1938, Cge 0.5125, Sge 0.2167
# # 03050, T 2037.0, Ltr 0.7169, Lge 0.7189, Ctr 0.5135, Str 0.1208, Cge 0.5417, Sge 0.2250
# # 03100, T 2070.2, Ltr 0.7159, Lge 0.7177, Ctr 0.5198, Str 0.1562, Cge 0.5083, Sge 0.1417
# # 03150, T 2103.3, Ltr 0.7164, Lge 0.7151, Ctr 0.5062, Str 0.0979, Cge 0.5417, Sge 0.1833
# # 03200, T 2136.4, Ltr 0.7162, Lge 0.7165, Ctr 0.4938, Str 0.1938, Cge 0.5292, Sge 0.2250
# # 03250, T 2169.5, Ltr 0.7152, Lge 0.7163, Ctr 0.5167, Str 0.2250, Cge 0.5417, Sge 0.1917
# # 03300, T 2202.6, Ltr 0.7145, Lge 0.7188, Ctr 0.5052, Str 0.1208, Cge 0.5042, Sge 0.0917
# # 03350, T 2235.7, Ltr 0.7144, Lge 0.7071, Ctr 0.5115, Str 0.1250, Cge 0.5500, Sge 0.1917
# # 03400, T 2268.8, Ltr 0.7148, Lge 0.7166, Ctr 0.5115, Str 0.1021, Cge 0.5292, Sge 0.1583
# # 03450, T 2302.1, Ltr 0.7147, Lge 0.7272, Ctr 0.4958, Str 0.1646, Cge 0.4792, Sge 0.0417
# # 03500, T 2335.4, Ltr 0.7131, Lge 0.7092, Ctr 0.5229, Str 0.1396, Cge 0.5250, Sge 0.1417
# # 03550, T 2368.4, Ltr 0.7134, Lge 0.7134, Ctr 0.5146, Str 0.1313, Cge 0.5167, Sge 0.1333
# # 03600, T 2401.1, Ltr 0.7120, Lge 0.7069, Ctr 0.5000, Str 0.0750, Cge 0.5250, Sge 0.0917
# # 03650, T 2434.3, Ltr 0.7143, Lge 0.7314, Ctr 0.4938, Str 0.1417, Cge 0.5333, Sge 0.2083
# # 03700, T 2467.2, Ltr 0.7120, Lge 0.7129, Ctr 0.5031, Str 0.1062, Cge 0.5417, Sge 0.1083
# # 03750, T 2500.1, Ltr 0.7093, Lge 0.7272, Ctr 0.5177, Str 0.1417, Cge 0.4750, Sge 0.1667
# # 03800, T 2533.0, Ltr 0.7113, Lge 0.7146, Ctr 0.5219, Str 0.1667, Cge 0.4917, Sge 0.1333
# # 03850, T 2566.3, Ltr 0.7118, Lge 0.7073, Ctr 0.5271, Str 0.1708, Cge 0.5125, Sge 0.1833
# # 03900, T 2599.5, Ltr 0.7097, Lge 0.7142, Ctr 0.5260, Str 0.1854, Cge 0.5375, Sge 0.1417
# # 03950, T 2632.6, Ltr 0.7104, Lge 0.7170, Ctr 0.5188, Str 0.1437, Cge 0.5125, Sge 0.1167
# # 04000, T 2665.4, Ltr 0.7103, Lge 0.7073, Ctr 0.5010, Str 0.1042, Cge 0.5125, Sge 0.1333
# # 04050, T 2698.2, Ltr 0.7103, Lge 0.7047, Ctr 0.5208, Str 0.1313, Cge 0.5125, Sge 0.1583
# # 04100, T 2731.3, Ltr 0.7084, Lge 0.7124, Ctr 0.5104, Str 0.1313, Cge 0.5208, Sge 0.1667
# # 04150, T 2764.2, Ltr 0.7090, Lge 0.7052, Ctr 0.5219, Str 0.1771, Cge 0.5375, Sge 0.1833
# # 04200, T 2797.1, Ltr 0.7072, Lge 0.7158, Ctr 0.5250, Str 0.1333, Cge 0.4958, Sge 0.0250
# # 04250, T 2829.5, Ltr 0.7093, Lge 0.7100, Ctr 0.5135, Str 0.1396, Cge 0.5375, Sge 0.1583
# # 04300, T 2861.8, Ltr 0.7078, Lge 0.7114, Ctr 0.5104, Str 0.1458, Cge 0.5333, Sge 0.1750
# # 04350, T 2894.4, Ltr 0.7088, Lge 0.7186, Ctr 0.5021, Str 0.1292, Cge 0.4917, Sge 0.1083
# # 04400, T 2927.6, Ltr 0.7067, Lge 0.7069, Ctr 0.5333, Str 0.1625, Cge 0.5667, Sge 0.2000
# # 04450, T 2960.6, Ltr 0.7121, Lge 0.7186, Ctr 0.5177, Str 0.1812, Cge 0.5083, Sge 0.1250
# # 04500, T 2993.3, Ltr 0.7057, Lge 0.7118, Ctr 0.5260, Str 0.1646, Cge 0.5292, Sge 0.2000
# # 04550, T 3025.9, Ltr 0.7076, Lge 0.7030, Ctr 0.5115, Str 0.1437, Cge 0.5375, Sge 0.1750
# # 04600, T 3058.6, Ltr 0.7060, Lge 0.7090, Ctr 0.5208, Str 0.1729, Cge 0.4792, Sge 0.1583
# # 04650, T 3091.4, Ltr 0.7057, Lge 0.6994, Ctr 0.5292, Str 0.2021, Cge 0.5833, Sge 0.2500
# # 04700, T 3124.5, Ltr 0.7041, Lge 0.7065, Ctr 0.5250, Str 0.1750, Cge 0.5375, Sge 0.1750
# # 04750, T 3157.4, Ltr 0.7048, Lge 0.7004, Ctr 0.5260, Str 0.1854, Cge 0.5667, Sge 0.2000
# # 04800, T 3190.5, Ltr 0.7045, Lge 0.7058, Ctr 0.5344, Str 0.1604, Cge 0.5542, Sge 0.2417
# # 04850, T 3223.6, Ltr 0.7037, Lge 0.7028, Ctr 0.5240, Str 0.1667, Cge 0.5250, Sge 0.1583
# # 04900, T 3256.5, Ltr 0.7035, Lge 0.7101, Ctr 0.5292, Str 0.1750, Cge 0.5208, Sge 0.1500
# # 04950, T 3289.6, Ltr 0.7033, Lge 0.7016, Ctr 0.5302, Str 0.1792, Cge 0.5417, Sge 0.2000

# %%
kgcn_vars = {
          'num_processing_steps_tr': 15, #13
          'num_processing_steps_ge': 15, #13
          'num_training_iterations': 5000, #10000?
          'learning_rate': 1e-5, #down to even 1e-4
          'latent_size': 16, #MLP param 16
          'num_layers': 2, #MLP param 2 (try deeper configs)
          'clip': 5, #gradient clipping 5
          'weighted': False, #loss function modification
          'log_every_epochs': 50, #logging of the results
          'node_types': node_types,
          'edge_types': edge_types,
          'continuous_attributes': CONTINUOUS_ATTRIBUTES,
          'categorical_attributes': CATEGORICAL_ATTRIBUTES,
          'output_dir': f"./events/500n2500/{time.time()}/",
          'save_fle': "training_summary.ckpt" 
          }           


ge_graphs, solveds_tr, solveds_ge  = go_train(train_graphs, tr_ge_split, **kgcn_vars)

#with session.transaction().write() as tx:
#        write_predictions_to_grakn(tr_ge_graphs, tx, commit = False)  # Write predictions to grakn with learned probabilities
    
#session.close()
#client.close()

#val_ge_graphs, validation_evals = go_train(val_graphs, val_ge_split, reload_fle = "test_model.ckpt", **kgcn_vars)    
# Close transaction, session and client due to write query

# %%
# !git add -A
# !git commit -m "colab training output"
# !git remote add origin https://Qbbz:oczywelza13@github.com/Qbbz/SSP.git
# !git push -u origin colab-branch
# Out:
# warning: adding embedded git repository: SSP
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> SSP
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached SSP
# hint:
# hint: See "git help submodule" for more information.
# ^C
# On branch master
# Untracked files:
# 	.config/
# 	SSP/
# 	gdrive/
# 	sample_data/
#
# nothing added to commit but untracked files present
# error: src refspec colab-branch does not match any.
# error: failed to push some refs to 'https://Qbbz:oczywelza13@github.com/Qbbz/SSP.git'
